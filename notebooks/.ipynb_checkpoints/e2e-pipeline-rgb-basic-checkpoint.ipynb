# %% [markdown]
# # E2E Pipeline RGB Basic
# Trying something different
# - Input satellite images
# - Do feature extraction without fine tuning
# - Linear regression on top of features extracted

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

import os
import PIL

pd.options.mode.chained_assignment = None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 import matplotlib.pylab as plt
#       6 import os
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# # Enable GPU

# %%
print('TensorFlow version: {}'.format(tf.__version__))
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU device not found - On for CPU time!')
else:
    print('Found GPU at {}'.format(device_name))
# Out:
# TensorFlow version: 2.12.0
# GPU device not found - On for CPU time!

# %% [markdown]
# # Understand images

# %%
import glob
path = '../outputs/tiled-satellite-images-rgb'

training_img = glob.glob(f'{path}/*.png')
print('There are {} images in the training directory'.format(len(training_img)))

img_sz = {'width': list(),
         'height': list()} # store image attributes for further analysis
width, height = 1000, 1000

for im in training_img:
    print(im)
    img = PIL.Image.open(im)
    w, h = img.size
    if w < width:
        width = w
    if h < height:
        height = h

IMG_WIDTH = width
IMG_HEIGHT = height
IMG_CHANNELS = 3

print('Min training image width: {} px'.format(IMG_WIDTH))
print('Min training image height: {} px'.format(IMG_HEIGHT))
# Out:
# There are 5850 images in the training directory
# ../outputs/tiled-satellite-images-rgb\0001.png
# ../outputs/tiled-satellite-images-rgb\0002.png
# ../outputs/tiled-satellite-images-rgb\0003.png
# ../outputs/tiled-satellite-images-rgb\0004.png
# ../outputs/tiled-satellite-images-rgb\0005.png
# ../outputs/tiled-satellite-images-rgb\0006.png
# ../outputs/tiled-satellite-images-rgb\0007.png
# ../outputs/tiled-satellite-images-rgb\0008.png
# ../outputs/tiled-satellite-images-rgb\0009.png
# ../outputs/tiled-satellite-images-rgb\0010.png
# ../outputs/tiled-satellite-images-rgb\0011.png
# ../outputs/tiled-satellite-images-rgb\0012.png
# ../outputs/tiled-satellite-images-rgb\0013.png
# ../outputs/tiled-satellite-images-rgb\0014.png
# ../outputs/tiled-satellite-images-rgb\0015.png
# ../outputs/tiled-satellite-images-rgb\0016.png
# ../outputs/tiled-satellite-images-rgb\0017.png
# ../outputs/tiled-satellite-images-rgb\0018.png
# ../outputs/tiled-satellite-images-rgb\0019.png
# ../outputs/tiled-satellite-images-rgb\0020.png
# ../outputs/tiled-satellite-images-rgb\0021.png
# ../outputs/tiled-satellite-images-rgb\0022.png
# ../outputs/tiled-satellite-images-rgb\0023.png
# ../outputs/tiled-satellite-images-rgb\0024.png
# ../outputs/tiled-satellite-images-rgb\0025.png
# ../outputs/tiled-satellite-images-rgb\0026.png
# ../outputs/tiled-satellite-images-rgb\0027.png
# ../outputs/tiled-satellite-images-rgb\0028.png
# ../outputs/tiled-satellite-images-rgb\0029.png
# ../outputs/tiled-satellite-images-rgb\0030.png
# ../outputs/tiled-satellite-images-rgb\0031.png
# ../outputs/tiled-satellite-images-rgb\0032.png
# ../outputs/tiled-satellite-images-rgb\0033.png
# ../outputs/tiled-satellite-images-rgb\0034.png
# ../outputs/tiled-satellite-images-rgb\0035.png
# ../outputs/tiled-satellite-images-rgb\0036.png
# ../outputs/tiled-satellite-images-rgb\0037.png
# ../outputs/tiled-satellite-images-rgb\0038.png
# ../outputs/tiled-satellite-images-rgb\0039.png
# ../outputs/tiled-satellite-images-rgb\0040.png
# ../outputs/tiled-satellite-images-rgb\0041.png
# ../outputs/tiled-satellite-images-rgb\0042.png
# ../outputs/tiled-satellite-images-rgb\0043.png
# ../outputs/tiled-satellite-images-rgb\0044.png
# ../outputs/tiled-satellite-images-rgb\0045.png
# ../outputs/tiled-satellite-images-rgb\0046.png
# ../outputs/tiled-satellite-images-rgb\0047.png
# ../outputs/tiled-satellite-images-rgb\0048.png
# ../outputs/tiled-satellite-images-rgb\0049.png
# ../outputs/tiled-satellite-images-rgb\0050.png
# ../outputs/tiled-satellite-images-rgb\0051.png
# ../outputs/tiled-satellite-images-rgb\0052.png
# ../outputs/tiled-satellite-images-rgb\0053.png
# ../outputs/tiled-satellite-images-rgb\0054.png
# ../outputs/tiled-satellite-images-rgb\0055.png
# ../outputs/tiled-satellite-images-rgb\0056.png
# ../outputs/tiled-satellite-images-rgb\0057.png
# ../outputs/tiled-satellite-images-rgb\0058.png
# ../outputs/tiled-satellite-images-rgb\0059.png
# ../outputs/tiled-satellite-images-rgb\0060.png
# ../outputs/tiled-satellite-images-rgb\0061.png
# ../outputs/tiled-satellite-images-rgb\0062.png
# ../outputs/tiled-satellite-images-rgb\0063.png
# ../outputs/tiled-satellite-images-rgb\0064.png
# ../outputs/tiled-satellite-images-rgb\0065.png
# ../outputs/tiled-satellite-images-rgb\0066.png
# ../outputs/tiled-satellite-images-rgb\0067.png
# ../outputs/tiled-satellite-images-rgb\0068.png
# ../outputs/tiled-satellite-images-rgb\0069.png
# ../outputs/tiled-satellite-images-rgb\0070.png
# ../outputs/tiled-satellite-images-rgb\0071.png
# ../outputs/tiled-satellite-images-rgb\0072.png
# ../outputs/tiled-satellite-images-rgb\0073.png
# ../outputs/tiled-satellite-images-rgb\0074.png
# ../outputs/tiled-satellite-images-rgb\0075.png
# ../outputs/tiled-satellite-images-rgb\0076.png
# ../outputs/tiled-satellite-images-rgb\0077.png
# ../outputs/tiled-satellite-images-rgb\0078.png
# ../outputs/tiled-satellite-images-rgb\0079.png
# ../outputs/tiled-satellite-images-rgb\0080.png
# ../outputs/tiled-satellite-images-rgb\0081.png
# ../outputs/tiled-satellite-images-rgb\0082.png
# ../outputs/tiled-satellite-images-rgb\0083.png
# ../outputs/tiled-satellite-images-rgb\0084.png
# ../outputs/tiled-satellite-images-rgb\0085.png
# ../outputs/tiled-satellite-images-rgb\0086.png
# ../outputs/tiled-satellite-images-rgb\0087.png
# ../outputs/tiled-satellite-images-rgb\0088.png
# ../outputs/tiled-satellite-images-rgb\0089.png
# ../outputs/tiled-satellite-images-rgb\0090.png
# ../outputs/tiled-satellite-images-rgb\0091.png
# ../outputs/tiled-satellite-images-rgb\0092.png
# ../outputs/tiled-satellite-images-rgb\0093.png
# ../outputs/tiled-satellite-images-rgb\0094.png
# ../outputs/tiled-satellite-images-rgb\0095.png
# ../outputs/tiled-satellite-images-rgb\0096.png
# ../outputs/tiled-satellite-images-rgb\0097.png
# ../outputs/tiled-satellite-images-rgb\0098.png
# ../outputs/tiled-satellite-images-rgb\0099.png
# ../outputs/tiled-satellite-images-rgb\0100.png
# ../outputs/tiled-satellite-images-rgb\0101.png
# ../outputs/tiled-satellite-images-rgb\0102.png
# ../outputs/tiled-satellite-images-rgb\0103.png
# ../outputs/tiled-satellite-images-rgb\0104.png
# ../outputs/tiled-satellite-images-rgb\0105.png
# ../outputs/tiled-satellite-images-rgb\0106.png
# ../outputs/tiled-satellite-images-rgb\0107.png
# ../outputs/tiled-satellite-images-rgb\0108.png
# ../outputs/tiled-satellite-images-rgb\0109.png
# ../outputs/tiled-satellite-images-rgb\0110.png
# ../outputs/tiled-satellite-images-rgb\0111.png
# ../outputs/tiled-satellite-images-rgb\0112.png
# ../outputs/tiled-satellite-images-rgb\0113.png
# ../outputs/tiled-satellite-images-rgb\0114.png
# ../outputs/tiled-satellite-images-rgb\0115.png
# ../outputs/tiled-satellite-images-rgb\0116.png
# ../outputs/tiled-satellite-images-rgb\0117.png
# ../outputs/tiled-satellite-images-rgb\0118.png
# ../outputs/tiled-satellite-images-rgb\0119.png
# ../outputs/tiled-satellite-images-rgb\0120.png
# ../outputs/tiled-satellite-images-rgb\0121.png
# ../outputs/tiled-satellite-images-rgb\0122.png
# ../outputs/tiled-satellite-images-rgb\0123.png
# ../outputs/tiled-satellite-images-rgb\0124.png
# ../outputs/tiled-satellite-images-rgb\0125.png
# ../outputs/tiled-satellite-images-rgb\0126.png
# ../outputs/tiled-satellite-images-rgb\0127.png
# ../outputs/tiled-satellite-images-rgb\0128.png
# ../outputs/tiled-satellite-images-rgb\0129.png
# ../outputs/tiled-satellite-images-rgb\0130.png
# ../outputs/tiled-satellite-images-rgb\0131.png
# ../outputs/tiled-satellite-images-rgb\0132.png
# ../outputs/tiled-satellite-images-rgb\0133.png
# ../outputs/tiled-satellite-images-rgb\0134.png
# ../outputs/tiled-satellite-images-rgb\0135.png
# ../outputs/tiled-satellite-images-rgb\0136.png
# ../outputs/tiled-satellite-images-rgb\0137.png
# ../outputs/tiled-satellite-images-rgb\0138.png
# ../outputs/tiled-satellite-images-rgb\0139.png
# ../outputs/tiled-satellite-images-rgb\0140.png
# ../outputs/tiled-satellite-images-rgb\0141.png
# ../outputs/tiled-satellite-images-rgb\0142.png
# ../outputs/tiled-satellite-images-rgb\0143.png
# ../outputs/tiled-satellite-images-rgb\0144.png
# ../outputs/tiled-satellite-images-rgb\0145.png
# ../outputs/tiled-satellite-images-rgb\0146.png
# ../outputs/tiled-satellite-images-rgb\0147.png
# ../outputs/tiled-satellite-images-rgb\0148.png
# ../outputs/tiled-satellite-images-rgb\0149.png
# ../outputs/tiled-satellite-images-rgb\0150.png
# ../outputs/tiled-satellite-images-rgb\0151.png
# ../outputs/tiled-satellite-images-rgb\0152.png
# ../outputs/tiled-satellite-images-rgb\0153.png
# ../outputs/tiled-satellite-images-rgb\0154.png
# ../outputs/tiled-satellite-images-rgb\0155.png
# ../outputs/tiled-satellite-images-rgb\0156.png
# ../outputs/tiled-satellite-images-rgb\0157.png
# ../outputs/tiled-satellite-images-rgb\0158.png
# ../outputs/tiled-satellite-images-rgb\0159.png
# ../outputs/tiled-satellite-images-rgb\0160.png
# ../outputs/tiled-satellite-images-rgb\0161.png
# ../outputs/tiled-satellite-images-rgb\0162.png
# ../outputs/tiled-satellite-images-rgb\0163.png
# ../outputs/tiled-satellite-images-rgb\0164.png
# ../outputs/tiled-satellite-images-rgb\0165.png
# ../outputs/tiled-satellite-images-rgb\0166.png
# ../outputs/tiled-satellite-images-rgb\0167.png
# ../outputs/tiled-satellite-images-rgb\0168.png
# ../outputs/tiled-satellite-images-rgb\0169.png
# ../outputs/tiled-satellite-images-rgb\0170.png
# ../outputs/tiled-satellite-images-rgb\0171.png
# ../outputs/tiled-satellite-images-rgb\0172.png
# ../outputs/tiled-satellite-images-rgb\0173.png
# ../outputs/tiled-satellite-images-rgb\0174.png
# ../outputs/tiled-satellite-images-rgb\0175.png
# ../outputs/tiled-satellite-images-rgb\0176.png
# ../outputs/tiled-satellite-images-rgb\0177.png
# ../outputs/tiled-satellite-images-rgb\0178.png
# ../outputs/tiled-satellite-images-rgb\0179.png
# ../outputs/tiled-satellite-images-rgb\0180.png
# ../outputs/tiled-satellite-images-rgb\0181.png
# ../outputs/tiled-satellite-images-rgb\0182.png
# ../outputs/tiled-satellite-images-rgb\0183.png
# ../outputs/tiled-satellite-images-rgb\0184.png
# ../outputs/tiled-satellite-images-rgb\0185.png
# ../outputs/tiled-satellite-images-rgb\0186.png
# ../outputs/tiled-satellite-images-rgb\0187.png
# ../outputs/tiled-satellite-images-rgb\0188.png
# ../outputs/tiled-satellite-images-rgb\0189.png
# ../outputs/tiled-satellite-images-rgb\0190.png
# ../outputs/tiled-satellite-images-rgb\0191.png
# ../outputs/tiled-satellite-images-rgb\0192.png
# ../outputs/tiled-satellite-images-rgb\0193.png
# ../outputs/tiled-satellite-images-rgb\0194.png
# ../outputs/tiled-satellite-images-rgb\0195.png
# ../outputs/tiled-satellite-images-rgb\0196.png
# ../outputs/tiled-satellite-images-rgb\0197.png
# ../outputs/tiled-satellite-images-rgb\0198.png
# ../outputs/tiled-satellite-images-rgb\0199.png
# ../outputs/tiled-satellite-images-rgb\0200.png
# ../outputs/tiled-satellite-images-rgb\0201.png
# ../outputs/tiled-satellite-images-rgb\0202.png
# ../outputs/tiled-satellite-images-rgb\0203.png
# ../outputs/tiled-satellite-images-rgb\0204.png
# ../outputs/tiled-satellite-images-rgb\0205.png
# ../outputs/tiled-satellite-images-rgb\0206.png
# ../outputs/tiled-satellite-images-rgb\0207.png
# ../outputs/tiled-satellite-images-rgb\0208.png
# ../outputs/tiled-satellite-images-rgb\0209.png
# ../outputs/tiled-satellite-images-rgb\0210.png
# ../outputs/tiled-satellite-images-rgb\0211.png
# ../outputs/tiled-satellite-images-rgb\0212.png
# ../outputs/tiled-satellite-images-rgb\0213.png
# ../outputs/tiled-satellite-images-rgb\0214.png
# ../outputs/tiled-satellite-images-rgb\0215.png
# ../outputs/tiled-satellite-images-rgb\0216.png
# ../outputs/tiled-satellite-images-rgb\0217.png
# ../outputs/tiled-satellite-images-rgb\0218.png
# ../outputs/tiled-satellite-images-rgb\0219.png
# ../outputs/tiled-satellite-images-rgb\0220.png
# ../outputs/tiled-satellite-images-rgb\0221.png
# ../outputs/tiled-satellite-images-rgb\0222.png
# ../outputs/tiled-satellite-images-rgb\0223.png
# ../outputs/tiled-satellite-images-rgb\0224.png
# ../outputs/tiled-satellite-images-rgb\0225.png
# ../outputs/tiled-satellite-images-rgb\0226.png
# ../outputs/tiled-satellite-images-rgb\0227.png
# ../outputs/tiled-satellite-images-rgb\0228.png
# ../outputs/tiled-satellite-images-rgb\0229.png
# ../outputs/tiled-satellite-images-rgb\0230.png
# ../outputs/tiled-satellite-images-rgb\0231.png
# ../outputs/tiled-satellite-images-rgb\0232.png
# ../outputs/tiled-satellite-images-rgb\0233.png
# ../outputs/tiled-satellite-images-rgb\0234.png
# ../outputs/tiled-satellite-images-rgb\0235.png
# ../outputs/tiled-satellite-images-rgb\0236.png
# ../outputs/tiled-satellite-images-rgb\0237.png
# ../outputs/tiled-satellite-images-rgb\0238.png
# ../outputs/tiled-satellite-images-rgb\0239.png
# ../outputs/tiled-satellite-images-rgb\0240.png
# ../outputs/tiled-satellite-images-rgb\0241.png
# ../outputs/tiled-satellite-images-rgb\0242.png
# ../outputs/tiled-satellite-images-rgb\0243.png
# ../outputs/tiled-satellite-images-rgb\0244.png
# ../outputs/tiled-satellite-images-rgb\0245.png
# ../outputs/tiled-satellite-images-rgb\0246.png
# ../outputs/tiled-satellite-images-rgb\0247.png
# ../outputs/tiled-satellite-images-rgb\0248.png
# ../outputs/tiled-satellite-images-rgb\0249.png
# ../outputs/tiled-satellite-images-rgb\0250.png
# ../outputs/tiled-satellite-images-rgb\0251.png
# ../outputs/tiled-satellite-images-rgb\0252.png
# ../outputs/tiled-satellite-images-rgb\0253.png
# ../outputs/tiled-satellite-images-rgb\0254.png
# ../outputs/tiled-satellite-images-rgb\0255.png
# ../outputs/tiled-satellite-images-rgb\0256.png
# ../outputs/tiled-satellite-images-rgb\0257.png
# ../outputs/tiled-satellite-images-rgb\0258.png
# ../outputs/tiled-satellite-images-rgb\0259.png
# ../outputs/tiled-satellite-images-rgb\0260.png
# ../outputs/tiled-satellite-images-rgb\0261.png
# ../outputs/tiled-satellite-images-rgb\0262.png
# ../outputs/tiled-satellite-images-rgb\0263.png
# ../outputs/tiled-satellite-images-rgb\0264.png
# ../outputs/tiled-satellite-images-rgb\0265.png
# ../outputs/tiled-satellite-images-rgb\0266.png
# ../outputs/tiled-satellite-images-rgb\0267.png
# ../outputs/tiled-satellite-images-rgb\0268.png
# ../outputs/tiled-satellite-images-rgb\0269.png
# ../outputs/tiled-satellite-images-rgb\0270.png
# ../outputs/tiled-satellite-images-rgb\0271.png
# ../outputs/tiled-satellite-images-rgb\0272.png
# ../outputs/tiled-satellite-images-rgb\0273.png
# ../outputs/tiled-satellite-images-rgb\0274.png
# ../outputs/tiled-satellite-images-rgb\0275.png
# ../outputs/tiled-satellite-images-rgb\0276.png
# ../outputs/tiled-satellite-images-rgb\0277.png
# ../outputs/tiled-satellite-images-rgb\0278.png
# ../outputs/tiled-satellite-images-rgb\0279.png
# ../outputs/tiled-satellite-images-rgb\0280.png
# ../outputs/tiled-satellite-images-rgb\0281.png
# ../outputs/tiled-satellite-images-rgb\0282.png
# ../outputs/tiled-satellite-images-rgb\0283.png
# ../outputs/tiled-satellite-images-rgb\0284.png
# ../outputs/tiled-satellite-images-rgb\0285.png
# ../outputs/tiled-satellite-images-rgb\0286.png
# ../outputs/tiled-satellite-images-rgb\0287.png
# ../outputs/tiled-satellite-images-rgb\0288.png
# ../outputs/tiled-satellite-images-rgb\0289.png
# ../outputs/tiled-satellite-images-rgb\0290.png
# ../outputs/tiled-satellite-images-rgb\0291.png
# ../outputs/tiled-satellite-images-rgb\0292.png
# ../outputs/tiled-satellite-images-rgb\0293.png
# ../outputs/tiled-satellite-images-rgb\0294.png
# ../outputs/tiled-satellite-images-rgb\0295.png
# ../outputs/tiled-satellite-images-rgb\0296.png
# ../outputs/tiled-satellite-images-rgb\0297.png
# ../outputs/tiled-satellite-images-rgb\0298.png
# ../outputs/tiled-satellite-images-rgb\0299.png
# ../outputs/tiled-satellite-images-rgb\0300.png
# ../outputs/tiled-satellite-images-rgb\0301.png
# ../outputs/tiled-satellite-images-rgb\0302.png
# ../outputs/tiled-satellite-images-rgb\0303.png
# ../outputs/tiled-satellite-images-rgb\0304.png
# ../outputs/tiled-satellite-images-rgb\0305.png
# ../outputs/tiled-satellite-images-rgb\0306.png
# ../outputs/tiled-satellite-images-rgb\0307.png
# ../outputs/tiled-satellite-images-rgb\0308.png
# ../outputs/tiled-satellite-images-rgb\0309.png
# ../outputs/tiled-satellite-images-rgb\0310.png
# ../outputs/tiled-satellite-images-rgb\0311.png
# ../outputs/tiled-satellite-images-rgb\0312.png
# ../outputs/tiled-satellite-images-rgb\0313.png
# ../outputs/tiled-satellite-images-rgb\0314.png
# ../outputs/tiled-satellite-images-rgb\0315.png
# ../outputs/tiled-satellite-images-rgb\0316.png
# ../outputs/tiled-satellite-images-rgb\0317.png
# ../outputs/tiled-satellite-images-rgb\0318.png
# ../outputs/tiled-satellite-images-rgb\0319.png
# ../outputs/tiled-satellite-images-rgb\0320.png
# ../outputs/tiled-satellite-images-rgb\0321.png
# ../outputs/tiled-satellite-images-rgb\0322.png
# ../outputs/tiled-satellite-images-rgb\0323.png
# ../outputs/tiled-satellite-images-rgb\0324.png
# ../outputs/tiled-satellite-images-rgb\0325.png
# ../outputs/tiled-satellite-images-rgb\0326.png
# ../outputs/tiled-satellite-images-rgb\0327.png
# ../outputs/tiled-satellite-images-rgb\0328.png
# ../outputs/tiled-satellite-images-rgb\0329.png
# ../outputs/tiled-satellite-images-rgb\0330.png
# ../outputs/tiled-satellite-images-rgb\0331.png
# ../outputs/tiled-satellite-images-rgb\0332.png
# ../outputs/tiled-satellite-images-rgb\0333.png
# ../outputs/tiled-satellite-images-rgb\0334.png
# ../outputs/tiled-satellite-images-rgb\0335.png
# ../outputs/tiled-satellite-images-rgb\0336.png
# ../outputs/tiled-satellite-images-rgb\0337.png
# ../outputs/tiled-satellite-images-rgb\0338.png
# ../outputs/tiled-satellite-images-rgb\0339.png
# ../outputs/tiled-satellite-images-rgb\0340.png
# ../outputs/tiled-satellite-images-rgb\0341.png
# ../outputs/tiled-satellite-images-rgb\0342.png
# ../outputs/tiled-satellite-images-rgb\0343.png
# ../outputs/tiled-satellite-images-rgb\0344.png
# ../outputs/tiled-satellite-images-rgb\0345.png
# ../outputs/tiled-satellite-images-rgb\0346.png
# ../outputs/tiled-satellite-images-rgb\0347.png
# ../outputs/tiled-satellite-images-rgb\0348.png
# ../outputs/tiled-satellite-images-rgb\0349.png
# ../outputs/tiled-satellite-images-rgb\0350.png
# ../outputs/tiled-satellite-images-rgb\0351.png
# ../outputs/tiled-satellite-images-rgb\0352.png
# ../outputs/tiled-satellite-images-rgb\0353.png
# ../outputs/tiled-satellite-images-rgb\0354.png
# ../outputs/tiled-satellite-images-rgb\0355.png
# ../outputs/tiled-satellite-images-rgb\0356.png
# ../outputs/tiled-satellite-images-rgb\0357.png
# ../outputs/tiled-satellite-images-rgb\0358.png
# ../outputs/tiled-satellite-images-rgb\0359.png
# ../outputs/tiled-satellite-images-rgb\0360.png
# ../outputs/tiled-satellite-images-rgb\0361.png
# ../outputs/tiled-satellite-images-rgb\0362.png
# ../outputs/tiled-satellite-images-rgb\0363.png
# ../outputs/tiled-satellite-images-rgb\0364.png
# ../outputs/tiled-satellite-images-rgb\0365.png
# ../outputs/tiled-satellite-images-rgb\0366.png
# ../outputs/tiled-satellite-images-rgb\0367.png
# ../outputs/tiled-satellite-images-rgb\0368.png
# ../outputs/tiled-satellite-images-rgb\0369.png
# ../outputs/tiled-satellite-images-rgb\0370.png
# ../outputs/tiled-satellite-images-rgb\0371.png
# ../outputs/tiled-satellite-images-rgb\0372.png
# ../outputs/tiled-satellite-images-rgb\0373.png
# ../outputs/tiled-satellite-images-rgb\0374.png
# ../outputs/tiled-satellite-images-rgb\0375.png
# ../outputs/tiled-satellite-images-rgb\0376.png
# ../outputs/tiled-satellite-images-rgb\0377.png
# ../outputs/tiled-satellite-images-rgb\0378.png
# ../outputs/tiled-satellite-images-rgb\0379.png
# ../outputs/tiled-satellite-images-rgb\0380.png
# ../outputs/tiled-satellite-images-rgb\0381.png
# ../outputs/tiled-satellite-images-rgb\0382.png
# ../outputs/tiled-satellite-images-rgb\0383.png
# ../outputs/tiled-satellite-images-rgb\0384.png
# ../outputs/tiled-satellite-images-rgb\0385.png
# ../outputs/tiled-satellite-images-rgb\0386.png
# ../outputs/tiled-satellite-images-rgb\0387.png
# ../outputs/tiled-satellite-images-rgb\0388.png
# ../outputs/tiled-satellite-images-rgb\0389.png
# ../outputs/tiled-satellite-images-rgb\0390.png
# ../outputs/tiled-satellite-images-rgb\0391.png
# ../outputs/tiled-satellite-images-rgb\0392.png
# ../outputs/tiled-satellite-images-rgb\0393.png
# ../outputs/tiled-satellite-images-rgb\0394.png
# ../outputs/tiled-satellite-images-rgb\0395.png
# ../outputs/tiled-satellite-images-rgb\0396.png
# ../outputs/tiled-satellite-images-rgb\0397.png
# ../outputs/tiled-satellite-images-rgb\0398.png
# ../outputs/tiled-satellite-images-rgb\0399.png
# ../outputs/tiled-satellite-images-rgb\0400.png
# ../outputs/tiled-satellite-images-rgb\0401.png
# ../outputs/tiled-satellite-images-rgb\0402.png
# ../outputs/tiled-satellite-images-rgb\0403.png
# ../outputs/tiled-satellite-images-rgb\0404.png
# ../outputs/tiled-satellite-images-rgb\0405.png
# ../outputs/tiled-satellite-images-rgb\0406.png
# ../outputs/tiled-satellite-images-rgb\0407.png
# ../outputs/tiled-satellite-images-rgb\0408.png
# ../outputs/tiled-satellite-images-rgb\0409.png
# ../outputs/tiled-satellite-images-rgb\0410.png
# ../outputs/tiled-satellite-images-rgb\0411.png
# ../outputs/tiled-satellite-images-rgb\0412.png
# ../outputs/tiled-satellite-images-rgb\0413.png
# ../outputs/tiled-satellite-images-rgb\0414.png
# ../outputs/tiled-satellite-images-rgb\0415.png
# ../outputs/tiled-satellite-images-rgb\0416.png
# ../outputs/tiled-satellite-images-rgb\0417.png
# ../outputs/tiled-satellite-images-rgb\0418.png
# ../outputs/tiled-satellite-images-rgb\0419.png
# ../outputs/tiled-satellite-images-rgb\0420.png
# ../outputs/tiled-satellite-images-rgb\0421.png
# ../outputs/tiled-satellite-images-rgb\0422.png
# ../outputs/tiled-satellite-images-rgb\0423.png
# ../outputs/tiled-satellite-images-rgb\0424.png
# ../outputs/tiled-satellite-images-rgb\0425.png
# ../outputs/tiled-satellite-images-rgb\0426.png
# ../outputs/tiled-satellite-images-rgb\0427.png
# ../outputs/tiled-satellite-images-rgb\0428.png
# ../outputs/tiled-satellite-images-rgb\0429.png
# ../outputs/tiled-satellite-images-rgb\0430.png
# ../outputs/tiled-satellite-images-rgb\0431.png
# ../outputs/tiled-satellite-images-rgb\0432.png
# ../outputs/tiled-satellite-images-rgb\0433.png
# ../outputs/tiled-satellite-images-rgb\0434.png
# ../outputs/tiled-satellite-images-rgb\0435.png
# ../outputs/tiled-satellite-images-rgb\0436.png
# ../outputs/tiled-satellite-images-rgb\0437.png
# ../outputs/tiled-satellite-images-rgb\0438.png
# ../outputs/tiled-satellite-images-rgb\0439.png
# ../outputs/tiled-satellite-images-rgb\0440.png
# ../outputs/tiled-satellite-images-rgb\0441.png
# ../outputs/tiled-satellite-images-rgb\0442.png
# ../outputs/tiled-satellite-images-rgb\0443.png
# ../outputs/tiled-satellite-images-rgb\0444.png
# ../outputs/tiled-satellite-images-rgb\0445.png
# ../outputs/tiled-satellite-images-rgb\0446.png
# ../outputs/tiled-satellite-images-rgb\0447.png
# ../outputs/tiled-satellite-images-rgb\0448.png
# ../outputs/tiled-satellite-images-rgb\0449.png
# ../outputs/tiled-satellite-images-rgb\0450.png
# ../outputs/tiled-satellite-images-rgb\0451.png
# ../outputs/tiled-satellite-images-rgb\0452.png
# ../outputs/tiled-satellite-images-rgb\0453.png
# ../outputs/tiled-satellite-images-rgb\0454.png
# ../outputs/tiled-satellite-images-rgb\0455.png
# ../outputs/tiled-satellite-images-rgb\0456.png
# ../outputs/tiled-satellite-images-rgb\0457.png
# ../outputs/tiled-satellite-images-rgb\0458.png
# ../outputs/tiled-satellite-images-rgb\0459.png
# ../outputs/tiled-satellite-images-rgb\0460.png
# ../outputs/tiled-satellite-images-rgb\0461.png
# ../outputs/tiled-satellite-images-rgb\0462.png
# ../outputs/tiled-satellite-images-rgb\0463.png
# ../outputs/tiled-satellite-images-rgb\0464.png
# ../outputs/tiled-satellite-images-rgb\0465.png
# ../outputs/tiled-satellite-images-rgb\0466.png
# ../outputs/tiled-satellite-images-rgb\0467.png
# ../outputs/tiled-satellite-images-rgb\0468.png
# ../outputs/tiled-satellite-images-rgb\0469.png
# ../outputs/tiled-satellite-images-rgb\0470.png
# ../outputs/tiled-satellite-images-rgb\0471.png
# ../outputs/tiled-satellite-images-rgb\0472.png
# ../outputs/tiled-satellite-images-rgb\0473.png
# ../outputs/tiled-satellite-images-rgb\0474.png
# ../outputs/tiled-satellite-images-rgb\0475.png
# ../outputs/tiled-satellite-images-rgb\0476.png
# ../outputs/tiled-satellite-images-rgb\0477.png
# ../outputs/tiled-satellite-images-rgb\0478.png
# ../outputs/tiled-satellite-images-rgb\0479.png
# ../outputs/tiled-satellite-images-rgb\0480.png
# ../outputs/tiled-satellite-images-rgb\0481.png
# ../outputs/tiled-satellite-images-rgb\0482.png
# ../outputs/tiled-satellite-images-rgb\0483.png
# ../outputs/tiled-satellite-images-rgb\0484.png
# ../outputs/tiled-satellite-images-rgb\0485.png
# ../outputs/tiled-satellite-images-rgb\0486.png
# ../outputs/tiled-satellite-images-rgb\0487.png
# ../outputs/tiled-satellite-images-rgb\0488.png
# ../outputs/tiled-satellite-images-rgb\0489.png
# ../outputs/tiled-satellite-images-rgb\0490.png
# ../outputs/tiled-satellite-images-rgb\0491.png
# ../outputs/tiled-satellite-images-rgb\0492.png
# ../outputs/tiled-satellite-images-rgb\0493.png
# ../outputs/tiled-satellite-images-rgb\0494.png
# ../outputs/tiled-satellite-images-rgb\0495.png
# ../outputs/tiled-satellite-images-rgb\0496.png
# ../outputs/tiled-satellite-images-rgb\0497.png
# ../outputs/tiled-satellite-images-rgb\0498.png
# ../outputs/tiled-satellite-images-rgb\0499.png
# ../outputs/tiled-satellite-images-rgb\0500.png
# ../outputs/tiled-satellite-images-rgb\0501.png
# ../outputs/tiled-satellite-images-rgb\0502.png
# ../outputs/tiled-satellite-images-rgb\0503.png
# ../outputs/tiled-satellite-images-rgb\0504.png
# ../outputs/tiled-satellite-images-rgb\0505.png
# ../outputs/tiled-satellite-images-rgb\0506.png
# ../outputs/tiled-satellite-images-rgb\0507.png
# ../outputs/tiled-satellite-images-rgb\0508.png
# ../outputs/tiled-satellite-images-rgb\0509.png
# ../outputs/tiled-satellite-images-rgb\0510.png
# ../outputs/tiled-satellite-images-rgb\0511.png
# ../outputs/tiled-satellite-images-rgb\0512.png
# ../outputs/tiled-satellite-images-rgb\0513.png
# ../outputs/tiled-satellite-images-rgb\0514.png
# ../outputs/tiled-satellite-images-rgb\0515.png
# ../outputs/tiled-satellite-images-rgb\0516.png
# ../outputs/tiled-satellite-images-rgb\0517.png
# ../outputs/tiled-satellite-images-rgb\0518.png
# ../outputs/tiled-satellite-images-rgb\0519.png
# ../outputs/tiled-satellite-images-rgb\0520.png
# ../outputs/tiled-satellite-images-rgb\0521.png
# ../outputs/tiled-satellite-images-rgb\0522.png
# ../outputs/tiled-satellite-images-rgb\0523.png
# ../outputs/tiled-satellite-images-rgb\0524.png
# ../outputs/tiled-satellite-images-rgb\0525.png
# ../outputs/tiled-satellite-images-rgb\0526.png
# ../outputs/tiled-satellite-images-rgb\0527.png
# ../outputs/tiled-satellite-images-rgb\0528.png
# ../outputs/tiled-satellite-images-rgb\0529.png
# ../outputs/tiled-satellite-images-rgb\0530.png
# ../outputs/tiled-satellite-images-rgb\0531.png
# ../outputs/tiled-satellite-images-rgb\0532.png
# ../outputs/tiled-satellite-images-rgb\0533.png
# ../outputs/tiled-satellite-images-rgb\0534.png
# ../outputs/tiled-satellite-images-rgb\0535.png
# ../outputs/tiled-satellite-images-rgb\0536.png
# ../outputs/tiled-satellite-images-rgb\0537.png
# ../outputs/tiled-satellite-images-rgb\0538.png
# ../outputs/tiled-satellite-images-rgb\0539.png
# ../outputs/tiled-satellite-images-rgb\0540.png
# ../outputs/tiled-satellite-images-rgb\0541.png
# ../outputs/tiled-satellite-images-rgb\0542.png
# ../outputs/tiled-satellite-images-rgb\0543.png
# ../outputs/tiled-satellite-images-rgb\0544.png
# ../outputs/tiled-satellite-images-rgb\0545.png
# ../outputs/tiled-satellite-images-rgb\0546.png
# ../outputs/tiled-satellite-images-rgb\0547.png
# ../outputs/tiled-satellite-images-rgb\0548.png
# ../outputs/tiled-satellite-images-rgb\0549.png
# ../outputs/tiled-satellite-images-rgb\0550.png
# ../outputs/tiled-satellite-images-rgb\0551.png
# ../outputs/tiled-satellite-images-rgb\0552.png
# ../outputs/tiled-satellite-images-rgb\0553.png
# ../outputs/tiled-satellite-images-rgb\0554.png
# ../outputs/tiled-satellite-images-rgb\0555.png
# ../outputs/tiled-satellite-images-rgb\0556.png
# ../outputs/tiled-satellite-images-rgb\0557.png
# ../outputs/tiled-satellite-images-rgb\0558.png
# ../outputs/tiled-satellite-images-rgb\0559.png
# ../outputs/tiled-satellite-images-rgb\0560.png
# ../outputs/tiled-satellite-images-rgb\0561.png
# ../outputs/tiled-satellite-images-rgb\0562.png
# ../outputs/tiled-satellite-images-rgb\0563.png
# ../outputs/tiled-satellite-images-rgb\0564.png
# ../outputs/tiled-satellite-images-rgb\0565.png
# ../outputs/tiled-satellite-images-rgb\0566.png
# ../outputs/tiled-satellite-images-rgb\0567.png
# ../outputs/tiled-satellite-images-rgb\0568.png
# ../outputs/tiled-satellite-images-rgb\0569.png
# ../outputs/tiled-satellite-images-rgb\0570.png
# ../outputs/tiled-satellite-images-rgb\0571.png
# ../outputs/tiled-satellite-images-rgb\0572.png
# ../outputs/tiled-satellite-images-rgb\0573.png
# ../outputs/tiled-satellite-images-rgb\0574.png
# ../outputs/tiled-satellite-images-rgb\0575.png
# ../outputs/tiled-satellite-images-rgb\0576.png
# ../outputs/tiled-satellite-images-rgb\0577.png
# ../outputs/tiled-satellite-images-rgb\0578.png
# ../outputs/tiled-satellite-images-rgb\0579.png
# ../outputs/tiled-satellite-images-rgb\0580.png
# ../outputs/tiled-satellite-images-rgb\0581.png
# ../outputs/tiled-satellite-images-rgb\0582.png
# ../outputs/tiled-satellite-images-rgb\0583.png
# ../outputs/tiled-satellite-images-rgb\0584.png
# ../outputs/tiled-satellite-images-rgb\0585.png
# ../outputs/tiled-satellite-images-rgb\0586.png
# ../outputs/tiled-satellite-images-rgb\0587.png
# ../outputs/tiled-satellite-images-rgb\0588.png
# ../outputs/tiled-satellite-images-rgb\0589.png
# ../outputs/tiled-satellite-images-rgb\0590.png
# ../outputs/tiled-satellite-images-rgb\0591.png
# ../outputs/tiled-satellite-images-rgb\0592.png
# ../outputs/tiled-satellite-images-rgb\0593.png
# ../outputs/tiled-satellite-images-rgb\0594.png
# ../outputs/tiled-satellite-images-rgb\0595.png
# ../outputs/tiled-satellite-images-rgb\0596.png
# ../outputs/tiled-satellite-images-rgb\0597.png
# ../outputs/tiled-satellite-images-rgb\0598.png
# ../outputs/tiled-satellite-images-rgb\0599.png
# ../outputs/tiled-satellite-images-rgb\0600.png
# ../outputs/tiled-satellite-images-rgb\0601.png
# ../outputs/tiled-satellite-images-rgb\0602.png
# ../outputs/tiled-satellite-images-rgb\0603.png
# ../outputs/tiled-satellite-images-rgb\0604.png
# ../outputs/tiled-satellite-images-rgb\0605.png
# ../outputs/tiled-satellite-images-rgb\0606.png
# ../outputs/tiled-satellite-images-rgb\0607.png
# ../outputs/tiled-satellite-images-rgb\0608.png
# ../outputs/tiled-satellite-images-rgb\0609.png
# ../outputs/tiled-satellite-images-rgb\0610.png
# ../outputs/tiled-satellite-images-rgb\0611.png
# ../outputs/tiled-satellite-images-rgb\0612.png
# ../outputs/tiled-satellite-images-rgb\0613.png
# ../outputs/tiled-satellite-images-rgb\0614.png
# ../outputs/tiled-satellite-images-rgb\0615.png
# ../outputs/tiled-satellite-images-rgb\0616.png
# ../outputs/tiled-satellite-images-rgb\0617.png
# ../outputs/tiled-satellite-images-rgb\0618.png
# ../outputs/tiled-satellite-images-rgb\0619.png
# ../outputs/tiled-satellite-images-rgb\0620.png
# ../outputs/tiled-satellite-images-rgb\0621.png
# ../outputs/tiled-satellite-images-rgb\0622.png
# ../outputs/tiled-satellite-images-rgb\0623.png
# ../outputs/tiled-satellite-images-rgb\0624.png
# ../outputs/tiled-satellite-images-rgb\0625.png
# ../outputs/tiled-satellite-images-rgb\0626.png
# ../outputs/tiled-satellite-images-rgb\0627.png
# ../outputs/tiled-satellite-images-rgb\0628.png
# ../outputs/tiled-satellite-images-rgb\0629.png
# ../outputs/tiled-satellite-images-rgb\0630.png
# ../outputs/tiled-satellite-images-rgb\0631.png
# ../outputs/tiled-satellite-images-rgb\0632.png
# ../outputs/tiled-satellite-images-rgb\0633.png
# ../outputs/tiled-satellite-images-rgb\0634.png
# ../outputs/tiled-satellite-images-rgb\0635.png
# ../outputs/tiled-satellite-images-rgb\0636.png
# ../outputs/tiled-satellite-images-rgb\0637.png
# ../outputs/tiled-satellite-images-rgb\0638.png
# ../outputs/tiled-satellite-images-rgb\0639.png
# ../outputs/tiled-satellite-images-rgb\0640.png
# ../outputs/tiled-satellite-images-rgb\0641.png
# ../outputs/tiled-satellite-images-rgb\0642.png
# ../outputs/tiled-satellite-images-rgb\0643.png
# ../outputs/tiled-satellite-images-rgb\0644.png
# ../outputs/tiled-satellite-images-rgb\0645.png
# ../outputs/tiled-satellite-images-rgb\0646.png
# ../outputs/tiled-satellite-images-rgb\0647.png
# ../outputs/tiled-satellite-images-rgb\0648.png
# ../outputs/tiled-satellite-images-rgb\0649.png
# ../outputs/tiled-satellite-images-rgb\0650.png
# ../outputs/tiled-satellite-images-rgb\0651.png
# ../outputs/tiled-satellite-images-rgb\0652.png
# ../outputs/tiled-satellite-images-rgb\0653.png
# ../outputs/tiled-satellite-images-rgb\0654.png
# ../outputs/tiled-satellite-images-rgb\0655.png
# ../outputs/tiled-satellite-images-rgb\0656.png
# ../outputs/tiled-satellite-images-rgb\0657.png
# ../outputs/tiled-satellite-images-rgb\0658.png
# ../outputs/tiled-satellite-images-rgb\0659.png
# ../outputs/tiled-satellite-images-rgb\0660.png
# ../outputs/tiled-satellite-images-rgb\0661.png
# ../outputs/tiled-satellite-images-rgb\0662.png
# ../outputs/tiled-satellite-images-rgb\0663.png
# ../outputs/tiled-satellite-images-rgb\0664.png
# ../outputs/tiled-satellite-images-rgb\0665.png
# ../outputs/tiled-satellite-images-rgb\0666.png
# ../outputs/tiled-satellite-images-rgb\0667.png
# ../outputs/tiled-satellite-images-rgb\0668.png
# ../outputs/tiled-satellite-images-rgb\0669.png
# ../outputs/tiled-satellite-images-rgb\0670.png
# ../outputs/tiled-satellite-images-rgb\0671.png
# ../outputs/tiled-satellite-images-rgb\0672.png
# ../outputs/tiled-satellite-images-rgb\0673.png
# ../outputs/tiled-satellite-images-rgb\0674.png
# ../outputs/tiled-satellite-images-rgb\0675.png
# ../outputs/tiled-satellite-images-rgb\0676.png
# ../outputs/tiled-satellite-images-rgb\0677.png
# ../outputs/tiled-satellite-images-rgb\0678.png
# ../outputs/tiled-satellite-images-rgb\0679.png
# ../outputs/tiled-satellite-images-rgb\0680.png
# ../outputs/tiled-satellite-images-rgb\0681.png
# ../outputs/tiled-satellite-images-rgb\0682.png
# ../outputs/tiled-satellite-images-rgb\0683.png
# ../outputs/tiled-satellite-images-rgb\0684.png
# ../outputs/tiled-satellite-images-rgb\0685.png
# ../outputs/tiled-satellite-images-rgb\0686.png
# ../outputs/tiled-satellite-images-rgb\0687.png
# ../outputs/tiled-satellite-images-rgb\0688.png
# ../outputs/tiled-satellite-images-rgb\0689.png
# ../outputs/tiled-satellite-images-rgb\0690.png
# ../outputs/tiled-satellite-images-rgb\0691.png
# ../outputs/tiled-satellite-images-rgb\0692.png
# ../outputs/tiled-satellite-images-rgb\0693.png
# ../outputs/tiled-satellite-images-rgb\0694.png
# ../outputs/tiled-satellite-images-rgb\0695.png
# ../outputs/tiled-satellite-images-rgb\0696.png
# ../outputs/tiled-satellite-images-rgb\0697.png
# ../outputs/tiled-satellite-images-rgb\0698.png
# ../outputs/tiled-satellite-images-rgb\0699.png
# ../outputs/tiled-satellite-images-rgb\0700.png
# ../outputs/tiled-satellite-images-rgb\0701.png
# ../outputs/tiled-satellite-images-rgb\0702.png
# ../outputs/tiled-satellite-images-rgb\0703.png
# ../outputs/tiled-satellite-images-rgb\0704.png
# ../outputs/tiled-satellite-images-rgb\0705.png
# ../outputs/tiled-satellite-images-rgb\0706.png
# ../outputs/tiled-satellite-images-rgb\0707.png
# ../outputs/tiled-satellite-images-rgb\0708.png
# ../outputs/tiled-satellite-images-rgb\0709.png
# ../outputs/tiled-satellite-images-rgb\0710.png
# ../outputs/tiled-satellite-images-rgb\0711.png
# ../outputs/tiled-satellite-images-rgb\0712.png
# ../outputs/tiled-satellite-images-rgb\0713.png
# ../outputs/tiled-satellite-images-rgb\0714.png
# ../outputs/tiled-satellite-images-rgb\0715.png
# ../outputs/tiled-satellite-images-rgb\0716.png
# ../outputs/tiled-satellite-images-rgb\0717.png
# ../outputs/tiled-satellite-images-rgb\0718.png
# ../outputs/tiled-satellite-images-rgb\0719.png
# ../outputs/tiled-satellite-images-rgb\0720.png
# ../outputs/tiled-satellite-images-rgb\0721.png
# ../outputs/tiled-satellite-images-rgb\0722.png
# ../outputs/tiled-satellite-images-rgb\0723.png
# ../outputs/tiled-satellite-images-rgb\0724.png
# ../outputs/tiled-satellite-images-rgb\0725.png
# ../outputs/tiled-satellite-images-rgb\0726.png
# ../outputs/tiled-satellite-images-rgb\0727.png
# ../outputs/tiled-satellite-images-rgb\0728.png
# ../outputs/tiled-satellite-images-rgb\0729.png
# ../outputs/tiled-satellite-images-rgb\0730.png
# ../outputs/tiled-satellite-images-rgb\0731.png
# ../outputs/tiled-satellite-images-rgb\0732.png
# ../outputs/tiled-satellite-images-rgb\0733.png
# ../outputs/tiled-satellite-images-rgb\0734.png
# ../outputs/tiled-satellite-images-rgb\0735.png
# ../outputs/tiled-satellite-images-rgb\0736.png
# ../outputs/tiled-satellite-images-rgb\0737.png
# ../outputs/tiled-satellite-images-rgb\0738.png
# ../outputs/tiled-satellite-images-rgb\0739.png
# ../outputs/tiled-satellite-images-rgb\0740.png
# ../outputs/tiled-satellite-images-rgb\0741.png
# ../outputs/tiled-satellite-images-rgb\0742.png
# ../outputs/tiled-satellite-images-rgb\0743.png
# ../outputs/tiled-satellite-images-rgb\0744.png
# ../outputs/tiled-satellite-images-rgb\0745.png
# ../outputs/tiled-satellite-images-rgb\0746.png
# ../outputs/tiled-satellite-images-rgb\0747.png
# ../outputs/tiled-satellite-images-rgb\0748.png
# ../outputs/tiled-satellite-images-rgb\0749.png
# ../outputs/tiled-satellite-images-rgb\0750.png
# ../outputs/tiled-satellite-images-rgb\0751.png
# ../outputs/tiled-satellite-images-rgb\0752.png
# ../outputs/tiled-satellite-images-rgb\0753.png
# ../outputs/tiled-satellite-images-rgb\0754.png
# ../outputs/tiled-satellite-images-rgb\0755.png
# ../outputs/tiled-satellite-images-rgb\0756.png
# ../outputs/tiled-satellite-images-rgb\0757.png
# ../outputs/tiled-satellite-images-rgb\0758.png
# ../outputs/tiled-satellite-images-rgb\0759.png
# ../outputs/tiled-satellite-images-rgb\0760.png
# ../outputs/tiled-satellite-images-rgb\0761.png
# ../outputs/tiled-satellite-images-rgb\0762.png
# ../outputs/tiled-satellite-images-rgb\0763.png
# ../outputs/tiled-satellite-images-rgb\0764.png
# ../outputs/tiled-satellite-images-rgb\0765.png
# ../outputs/tiled-satellite-images-rgb\0766.png
# ../outputs/tiled-satellite-images-rgb\0767.png
# ../outputs/tiled-satellite-images-rgb\0768.png
# ../outputs/tiled-satellite-images-rgb\0769.png
# ../outputs/tiled-satellite-images-rgb\0770.png
# ../outputs/tiled-satellite-images-rgb\0771.png
# ../outputs/tiled-satellite-images-rgb\0772.png
# ../outputs/tiled-satellite-images-rgb\0773.png
# ../outputs/tiled-satellite-images-rgb\0774.png
# ../outputs/tiled-satellite-images-rgb\0775.png
# ../outputs/tiled-satellite-images-rgb\0776.png
# ../outputs/tiled-satellite-images-rgb\0777.png
# ../outputs/tiled-satellite-images-rgb\0778.png
# ../outputs/tiled-satellite-images-rgb\0779.png
# ../outputs/tiled-satellite-images-rgb\0780.png
# ../outputs/tiled-satellite-images-rgb\0781.png
# ../outputs/tiled-satellite-images-rgb\0782.png
# ../outputs/tiled-satellite-images-rgb\0783.png
# ../outputs/tiled-satellite-images-rgb\0784.png
# ../outputs/tiled-satellite-images-rgb\0785.png
# ../outputs/tiled-satellite-images-rgb\0786.png
# ../outputs/tiled-satellite-images-rgb\0787.png
# ../outputs/tiled-satellite-images-rgb\0788.png
# ../outputs/tiled-satellite-images-rgb\0789.png
# ../outputs/tiled-satellite-images-rgb\0790.png
# ../outputs/tiled-satellite-images-rgb\0791.png
# ../outputs/tiled-satellite-images-rgb\0792.png
# ../outputs/tiled-satellite-images-rgb\0793.png
# ../outputs/tiled-satellite-images-rgb\0794.png
# ../outputs/tiled-satellite-images-rgb\0795.png
# ../outputs/tiled-satellite-images-rgb\0796.png
# ../outputs/tiled-satellite-images-rgb\0797.png
# ../outputs/tiled-satellite-images-rgb\0798.png
# ../outputs/tiled-satellite-images-rgb\0799.png
# ../outputs/tiled-satellite-images-rgb\0800.png
# ../outputs/tiled-satellite-images-rgb\0801.png
# ../outputs/tiled-satellite-images-rgb\0802.png
# ../outputs/tiled-satellite-images-rgb\0803.png
# ../outputs/tiled-satellite-images-rgb\0804.png
# ../outputs/tiled-satellite-images-rgb\0805.png
# ../outputs/tiled-satellite-images-rgb\0806.png
# ../outputs/tiled-satellite-images-rgb\0807.png
# ../outputs/tiled-satellite-images-rgb\0808.png
# ../outputs/tiled-satellite-images-rgb\0809.png
# ../outputs/tiled-satellite-images-rgb\0810.png
# ../outputs/tiled-satellite-images-rgb\0811.png
# ../outputs/tiled-satellite-images-rgb\0812.png
# ../outputs/tiled-satellite-images-rgb\0813.png
# ../outputs/tiled-satellite-images-rgb\0814.png
# ../outputs/tiled-satellite-images-rgb\0815.png
# ../outputs/tiled-satellite-images-rgb\0816.png
# ../outputs/tiled-satellite-images-rgb\0817.png
# ../outputs/tiled-satellite-images-rgb\0818.png
# ../outputs/tiled-satellite-images-rgb\0819.png
# ../outputs/tiled-satellite-images-rgb\0820.png
# ../outputs/tiled-satellite-images-rgb\0821.png
# ../outputs/tiled-satellite-images-rgb\0822.png
# ../outputs/tiled-satellite-images-rgb\0823.png
# ../outputs/tiled-satellite-images-rgb\0824.png
# ../outputs/tiled-satellite-images-rgb\0825.png
# ../outputs/tiled-satellite-images-rgb\0826.png
# ../outputs/tiled-satellite-images-rgb\0827.png
# ../outputs/tiled-satellite-images-rgb\0828.png
# ../outputs/tiled-satellite-images-rgb\0829.png
# ../outputs/tiled-satellite-images-rgb\0830.png
# ../outputs/tiled-satellite-images-rgb\0831.png
# ../outputs/tiled-satellite-images-rgb\0832.png
# ../outputs/tiled-satellite-images-rgb\0833.png
# ../outputs/tiled-satellite-images-rgb\0834.png
# ../outputs/tiled-satellite-images-rgb\0835.png
# ../outputs/tiled-satellite-images-rgb\0836.png
# ../outputs/tiled-satellite-images-rgb\0837.png
# ../outputs/tiled-satellite-images-rgb\0838.png
# ../outputs/tiled-satellite-images-rgb\0839.png
# ../outputs/tiled-satellite-images-rgb\0840.png
# ../outputs/tiled-satellite-images-rgb\0841.png
# ../outputs/tiled-satellite-images-rgb\0842.png
# ../outputs/tiled-satellite-images-rgb\0843.png
# ../outputs/tiled-satellite-images-rgb\0844.png
# ../outputs/tiled-satellite-images-rgb\0845.png
# ../outputs/tiled-satellite-images-rgb\0846.png
# ../outputs/tiled-satellite-images-rgb\0847.png
# ../outputs/tiled-satellite-images-rgb\0848.png
# ../outputs/tiled-satellite-images-rgb\0849.png
# ../outputs/tiled-satellite-images-rgb\0850.png
# ../outputs/tiled-satellite-images-rgb\0851.png
# ../outputs/tiled-satellite-images-rgb\0852.png
# ../outputs/tiled-satellite-images-rgb\0853.png
# ../outputs/tiled-satellite-images-rgb\0854.png
# ../outputs/tiled-satellite-images-rgb\0855.png
# ../outputs/tiled-satellite-images-rgb\0856.png
# ../outputs/tiled-satellite-images-rgb\0857.png
# ../outputs/tiled-satellite-images-rgb\0858.png
# ../outputs/tiled-satellite-images-rgb\0859.png
# ../outputs/tiled-satellite-images-rgb\0860.png
# ../outputs/tiled-satellite-images-rgb\0861.png
# ../outputs/tiled-satellite-images-rgb\0862.png
# ../outputs/tiled-satellite-images-rgb\0863.png
# ../outputs/tiled-satellite-images-rgb\0864.png
# ../outputs/tiled-satellite-images-rgb\0865.png
# ../outputs/tiled-satellite-images-rgb\0866.png
# ../outputs/tiled-satellite-images-rgb\0867.png
# ../outputs/tiled-satellite-images-rgb\0868.png
# ../outputs/tiled-satellite-images-rgb\0869.png
# ../outputs/tiled-satellite-images-rgb\0870.png
# ../outputs/tiled-satellite-images-rgb\0871.png
# ../outputs/tiled-satellite-images-rgb\0872.png
# ../outputs/tiled-satellite-images-rgb\0873.png
# ../outputs/tiled-satellite-images-rgb\0874.png
# ../outputs/tiled-satellite-images-rgb\0875.png
# ../outputs/tiled-satellite-images-rgb\0876.png
# ../outputs/tiled-satellite-images-rgb\0877.png
# ../outputs/tiled-satellite-images-rgb\0878.png
# ../outputs/tiled-satellite-images-rgb\0879.png
# ../outputs/tiled-satellite-images-rgb\0880.png
# ../outputs/tiled-satellite-images-rgb\0881.png
# ../outputs/tiled-satellite-images-rgb\0882.png
# ../outputs/tiled-satellite-images-rgb\0883.png
# ../outputs/tiled-satellite-images-rgb\0884.png
# ../outputs/tiled-satellite-images-rgb\0885.png
# ../outputs/tiled-satellite-images-rgb\0886.png
# ../outputs/tiled-satellite-images-rgb\0887.png
# ../outputs/tiled-satellite-images-rgb\0888.png
# ../outputs/tiled-satellite-images-rgb\0889.png
# ../outputs/tiled-satellite-images-rgb\0890.png
# ../outputs/tiled-satellite-images-rgb\0891.png
# ../outputs/tiled-satellite-images-rgb\0892.png
# ../outputs/tiled-satellite-images-rgb\0893.png
# ../outputs/tiled-satellite-images-rgb\0894.png
# ../outputs/tiled-satellite-images-rgb\0895.png
# ../outputs/tiled-satellite-images-rgb\0896.png
# ../outputs/tiled-satellite-images-rgb\0897.png
# ../outputs/tiled-satellite-images-rgb\0898.png
# ../outputs/tiled-satellite-images-rgb\0899.png
# ../outputs/tiled-satellite-images-rgb\0900.png
# ../outputs/tiled-satellite-images-rgb\0901.png
# ../outputs/tiled-satellite-images-rgb\0902.png
# ../outputs/tiled-satellite-images-rgb\0903.png
# ../outputs/tiled-satellite-images-rgb\0904.png
# ../outputs/tiled-satellite-images-rgb\0905.png
# ../outputs/tiled-satellite-images-rgb\0906.png
# ../outputs/tiled-satellite-images-rgb\0907.png
# ../outputs/tiled-satellite-images-rgb\0908.png
# ../outputs/tiled-satellite-images-rgb\0909.png
# ../outputs/tiled-satellite-images-rgb\0910.png
# ../outputs/tiled-satellite-images-rgb\0911.png
# ../outputs/tiled-satellite-images-rgb\0912.png
# ../outputs/tiled-satellite-images-rgb\0913.png
# ../outputs/tiled-satellite-images-rgb\0914.png
# ../outputs/tiled-satellite-images-rgb\0915.png
# ../outputs/tiled-satellite-images-rgb\0916.png
# ../outputs/tiled-satellite-images-rgb\0917.png
# ../outputs/tiled-satellite-images-rgb\0918.png
# ../outputs/tiled-satellite-images-rgb\0919.png
# ../outputs/tiled-satellite-images-rgb\0920.png
# ../outputs/tiled-satellite-images-rgb\0921.png
# ../outputs/tiled-satellite-images-rgb\0922.png
# ../outputs/tiled-satellite-images-rgb\0923.png
# ../outputs/tiled-satellite-images-rgb\0924.png
# ../outputs/tiled-satellite-images-rgb\0925.png
# ../outputs/tiled-satellite-images-rgb\0926.png
# ../outputs/tiled-satellite-images-rgb\0927.png
# ../outputs/tiled-satellite-images-rgb\0928.png
# ../outputs/tiled-satellite-images-rgb\0929.png
# ../outputs/tiled-satellite-images-rgb\0930.png
# ../outputs/tiled-satellite-images-rgb\0931.png
# ../outputs/tiled-satellite-images-rgb\0932.png
# ../outputs/tiled-satellite-images-rgb\0933.png
# ../outputs/tiled-satellite-images-rgb\0934.png
# ../outputs/tiled-satellite-images-rgb\0935.png
# ../outputs/tiled-satellite-images-rgb\0936.png
# ../outputs/tiled-satellite-images-rgb\0937.png
# ../outputs/tiled-satellite-images-rgb\0938.png
# ../outputs/tiled-satellite-images-rgb\0939.png
# ../outputs/tiled-satellite-images-rgb\0940.png
# ../outputs/tiled-satellite-images-rgb\0941.png
# ../outputs/tiled-satellite-images-rgb\0942.png
# ../outputs/tiled-satellite-images-rgb\0943.png
# ../outputs/tiled-satellite-images-rgb\0944.png
# ../outputs/tiled-satellite-images-rgb\0945.png
# ../outputs/tiled-satellite-images-rgb\0946.png
# ../outputs/tiled-satellite-images-rgb\0947.png
# ../outputs/tiled-satellite-images-rgb\0948.png
# ../outputs/tiled-satellite-images-rgb\0949.png
# ../outputs/tiled-satellite-images-rgb\0950.png
# ../outputs/tiled-satellite-images-rgb\0951.png
# ../outputs/tiled-satellite-images-rgb\0952.png
# ../outputs/tiled-satellite-images-rgb\0953.png
# ../outputs/tiled-satellite-images-rgb\0954.png
# ../outputs/tiled-satellite-images-rgb\0955.png
# ../outputs/tiled-satellite-images-rgb\0956.png
# ../outputs/tiled-satellite-images-rgb\0957.png
# ../outputs/tiled-satellite-images-rgb\0958.png
# ../outputs/tiled-satellite-images-rgb\0959.png
# ../outputs/tiled-satellite-images-rgb\0960.png
# ../outputs/tiled-satellite-images-rgb\0961.png
# ../outputs/tiled-satellite-images-rgb\0962.png
# ../outputs/tiled-satellite-images-rgb\0963.png
# ../outputs/tiled-satellite-images-rgb\0964.png
# ../outputs/tiled-satellite-images-rgb\0965.png
# ../outputs/tiled-satellite-images-rgb\0966.png
# ../outputs/tiled-satellite-images-rgb\0967.png
# ../outputs/tiled-satellite-images-rgb\0968.png
# ../outputs/tiled-satellite-images-rgb\0969.png
# ../outputs/tiled-satellite-images-rgb\0970.png
# ../outputs/tiled-satellite-images-rgb\0971.png
# ../outputs/tiled-satellite-images-rgb\0972.png
# ../outputs/tiled-satellite-images-rgb\0973.png
# ../outputs/tiled-satellite-images-rgb\0974.png
# ../outputs/tiled-satellite-images-rgb\0975.png
# ../outputs/tiled-satellite-images-rgb\0976.png
# ../outputs/tiled-satellite-images-rgb\0977.png
# ../outputs/tiled-satellite-images-rgb\0978.png
# ../outputs/tiled-satellite-images-rgb\0979.png
# ../outputs/tiled-satellite-images-rgb\0980.png
# ../outputs/tiled-satellite-images-rgb\0981.png
# ../outputs/tiled-satellite-images-rgb\0982.png
# ../outputs/tiled-satellite-images-rgb\0983.png
# ../outputs/tiled-satellite-images-rgb\0984.png
# ../outputs/tiled-satellite-images-rgb\0985.png
# ../outputs/tiled-satellite-images-rgb\0986.png
# ../outputs/tiled-satellite-images-rgb\0987.png
# ../outputs/tiled-satellite-images-rgb\0988.png
# ../outputs/tiled-satellite-images-rgb\0989.png
# ../outputs/tiled-satellite-images-rgb\0990.png
# ../outputs/tiled-satellite-images-rgb\0991.png
# ../outputs/tiled-satellite-images-rgb\0992.png
# ../outputs/tiled-satellite-images-rgb\0993.png
# ../outputs/tiled-satellite-images-rgb\0994.png
# ../outputs/tiled-satellite-images-rgb\0995.png
# ../outputs/tiled-satellite-images-rgb\0996.png
# ../outputs/tiled-satellite-images-rgb\0997.png
# ../outputs/tiled-satellite-images-rgb\0998.png
# ../outputs/tiled-satellite-images-rgb\0999.png
# ../outputs/tiled-satellite-images-rgb\1000.png
# ../outputs/tiled-satellite-images-rgb\1001.png
# ../outputs/tiled-satellite-images-rgb\1002.png
# ../outputs/tiled-satellite-images-rgb\1003.png
# ../outputs/tiled-satellite-images-rgb\1004.png
# ../outputs/tiled-satellite-images-rgb\1005.png
# ../outputs/tiled-satellite-images-rgb\1006.png
# ../outputs/tiled-satellite-images-rgb\1007.png
# ../outputs/tiled-satellite-images-rgb\1008.png
# ../outputs/tiled-satellite-images-rgb\1009.png
# ../outputs/tiled-satellite-images-rgb\1010.png
# ../outputs/tiled-satellite-images-rgb\1011.png
# ../outputs/tiled-satellite-images-rgb\1012.png
# ../outputs/tiled-satellite-images-rgb\1013.png
# ../outputs/tiled-satellite-images-rgb\1014.png
# ../outputs/tiled-satellite-images-rgb\1015.png
# ../outputs/tiled-satellite-images-rgb\1016.png
# ../outputs/tiled-satellite-images-rgb\1017.png
# ../outputs/tiled-satellite-images-rgb\1018.png
# ../outputs/tiled-satellite-images-rgb\1019.png
# ../outputs/tiled-satellite-images-rgb\1020.png
# ...
# ../outputs/tiled-satellite-images-rgb\5512.png
# ../outputs/tiled-satellite-images-rgb\5513.png
# ../outputs/tiled-satellite-images-rgb\5514.png
# ../outputs/tiled-satellite-images-rgb\5515.png
# ../outputs/tiled-satellite-images-rgb\5516.png
# ../outputs/tiled-satellite-images-rgb\5517.png
# ../outputs/tiled-satellite-images-rgb\5518.png
# ../outputs/tiled-satellite-images-rgb\5519.png
# ../outputs/tiled-satellite-images-rgb\5520.png
# ../outputs/tiled-satellite-images-rgb\5521.png
# ../outputs/tiled-satellite-images-rgb\5522.png
# ../outputs/tiled-satellite-images-rgb\5523.png
# ../outputs/tiled-satellite-images-rgb\5524.png
# ../outputs/tiled-satellite-images-rgb\5525.png
# ../outputs/tiled-satellite-images-rgb\5526.png
# ../outputs/tiled-satellite-images-rgb\5527.png
# ../outputs/tiled-satellite-images-rgb\5528.png
# ../outputs/tiled-satellite-images-rgb\5529.png
# ../outputs/tiled-satellite-images-rgb\5530.png
# ../outputs/tiled-satellite-images-rgb\5531.png
# ../outputs/tiled-satellite-images-rgb\5532.png
# ../outputs/tiled-satellite-images-rgb\5533.png
# ../outputs/tiled-satellite-images-rgb\5534.png
# ../outputs/tiled-satellite-images-rgb\5535.png
# ../outputs/tiled-satellite-images-rgb\5536.png
# ../outputs/tiled-satellite-images-rgb\5537.png
# ../outputs/tiled-satellite-images-rgb\5538.png
# ../outputs/tiled-satellite-images-rgb\5539.png
# ../outputs/tiled-satellite-images-rgb\5540.png
# ../outputs/tiled-satellite-images-rgb\5541.png
# ../outputs/tiled-satellite-images-rgb\5542.png
# ../outputs/tiled-satellite-images-rgb\5543.png
# ../outputs/tiled-satellite-images-rgb\5544.png
# ../outputs/tiled-satellite-images-rgb\5545.png
# ../outputs/tiled-satellite-images-rgb\5546.png
# ../outputs/tiled-satellite-images-rgb\5547.png
# ../outputs/tiled-satellite-images-rgb\5548.png
# ../outputs/tiled-satellite-images-rgb\5549.png
# ../outputs/tiled-satellite-images-rgb\5550.png
# ../outputs/tiled-satellite-images-rgb\5551.png
# ../outputs/tiled-satellite-images-rgb\5552.png
# ../outputs/tiled-satellite-images-rgb\5553.png
# ../outputs/tiled-satellite-images-rgb\5554.png
# ../outputs/tiled-satellite-images-rgb\5555.png
# ../outputs/tiled-satellite-images-rgb\5556.png
# ../outputs/tiled-satellite-images-rgb\5557.png
# ../outputs/tiled-satellite-images-rgb\5558.png
# ../outputs/tiled-satellite-images-rgb\5559.png
# ../outputs/tiled-satellite-images-rgb\5560.png
# ../outputs/tiled-satellite-images-rgb\5561.png
# ../outputs/tiled-satellite-images-rgb\5562.png
# ../outputs/tiled-satellite-images-rgb\5563.png
# ../outputs/tiled-satellite-images-rgb\5564.png
# ../outputs/tiled-satellite-images-rgb\5565.png
# ../outputs/tiled-satellite-images-rgb\5566.png
# ../outputs/tiled-satellite-images-rgb\5567.png
# ../outputs/tiled-satellite-images-rgb\5568.png
# ../outputs/tiled-satellite-images-rgb\5569.png
# ../outputs/tiled-satellite-images-rgb\5570.png
# ../outputs/tiled-satellite-images-rgb\5571.png
# ../outputs/tiled-satellite-images-rgb\5572.png
# ../outputs/tiled-satellite-images-rgb\5573.png
# ../outputs/tiled-satellite-images-rgb\5574.png
# ../outputs/tiled-satellite-images-rgb\5575.png
# ../outputs/tiled-satellite-images-rgb\5576.png
# ../outputs/tiled-satellite-images-rgb\5577.png
# ../outputs/tiled-satellite-images-rgb\5578.png
# ../outputs/tiled-satellite-images-rgb\5579.png
# ../outputs/tiled-satellite-images-rgb\5580.png
# ../outputs/tiled-satellite-images-rgb\5581.png
# ../outputs/tiled-satellite-images-rgb\5582.png
# ../outputs/tiled-satellite-images-rgb\5583.png
# ../outputs/tiled-satellite-images-rgb\5584.png
# ../outputs/tiled-satellite-images-rgb\5585.png
# ../outputs/tiled-satellite-images-rgb\5586.png
# ../outputs/tiled-satellite-images-rgb\5587.png
# ../outputs/tiled-satellite-images-rgb\5588.png
# ../outputs/tiled-satellite-images-rgb\5589.png
# ../outputs/tiled-satellite-images-rgb\5590.png
# ../outputs/tiled-satellite-images-rgb\5591.png
# ../outputs/tiled-satellite-images-rgb\5592.png
# ../outputs/tiled-satellite-images-rgb\5593.png
# ../outputs/tiled-satellite-images-rgb\5594.png
# ../outputs/tiled-satellite-images-rgb\5595.png
# ../outputs/tiled-satellite-images-rgb\5596.png
# ../outputs/tiled-satellite-images-rgb\5597.png
# ../outputs/tiled-satellite-images-rgb\5598.png
# ../outputs/tiled-satellite-images-rgb\5599.png
# ../outputs/tiled-satellite-images-rgb\5600.png
# ../outputs/tiled-satellite-images-rgb\5601.png
# ../outputs/tiled-satellite-images-rgb\5602.png
# ../outputs/tiled-satellite-images-rgb\5603.png
# ../outputs/tiled-satellite-images-rgb\5604.png
# ../outputs/tiled-satellite-images-rgb\5605.png
# ../outputs/tiled-satellite-images-rgb\5606.png
# ../outputs/tiled-satellite-images-rgb\5607.png
# ../outputs/tiled-satellite-images-rgb\5608.png
# ../outputs/tiled-satellite-images-rgb\5609.png
# ../outputs/tiled-satellite-images-rgb\5610.png
# ../outputs/tiled-satellite-images-rgb\5611.png
# ../outputs/tiled-satellite-images-rgb\5612.png
# ../outputs/tiled-satellite-images-rgb\5613.png
# ../outputs/tiled-satellite-images-rgb\5614.png
# ../outputs/tiled-satellite-images-rgb\5615.png
# ../outputs/tiled-satellite-images-rgb\5616.png
# ../outputs/tiled-satellite-images-rgb\5617.png
# ../outputs/tiled-satellite-images-rgb\5618.png
# ../outputs/tiled-satellite-images-rgb\5619.png
# ../outputs/tiled-satellite-images-rgb\5620.png
# ../outputs/tiled-satellite-images-rgb\5621.png
# ../outputs/tiled-satellite-images-rgb\5622.png
# ../outputs/tiled-satellite-images-rgb\5623.png
# ../outputs/tiled-satellite-images-rgb\5624.png
# ../outputs/tiled-satellite-images-rgb\5625.png
# ../outputs/tiled-satellite-images-rgb\5626.png
# ../outputs/tiled-satellite-images-rgb\5627.png
# ../outputs/tiled-satellite-images-rgb\5628.png
# ../outputs/tiled-satellite-images-rgb\5629.png
# ../outputs/tiled-satellite-images-rgb\5630.png
# ../outputs/tiled-satellite-images-rgb\5631.png
# ../outputs/tiled-satellite-images-rgb\5632.png
# ../outputs/tiled-satellite-images-rgb\5633.png
# ../outputs/tiled-satellite-images-rgb\5634.png
# ../outputs/tiled-satellite-images-rgb\5635.png
# ../outputs/tiled-satellite-images-rgb\5636.png
# ../outputs/tiled-satellite-images-rgb\5637.png
# ../outputs/tiled-satellite-images-rgb\5638.png
# ../outputs/tiled-satellite-images-rgb\5639.png
# ../outputs/tiled-satellite-images-rgb\5640.png
# ../outputs/tiled-satellite-images-rgb\5641.png
# ../outputs/tiled-satellite-images-rgb\5642.png
# ../outputs/tiled-satellite-images-rgb\5643.png
# ../outputs/tiled-satellite-images-rgb\5644.png
# ../outputs/tiled-satellite-images-rgb\5645.png
# ../outputs/tiled-satellite-images-rgb\5646.png
# ../outputs/tiled-satellite-images-rgb\5647.png
# ../outputs/tiled-satellite-images-rgb\5648.png
# ../outputs/tiled-satellite-images-rgb\5649.png
# ../outputs/tiled-satellite-images-rgb\5650.png
# ../outputs/tiled-satellite-images-rgb\5651.png
# ../outputs/tiled-satellite-images-rgb\5652.png
# ../outputs/tiled-satellite-images-rgb\5653.png
# ../outputs/tiled-satellite-images-rgb\5654.png
# ../outputs/tiled-satellite-images-rgb\5655.png
# ../outputs/tiled-satellite-images-rgb\5656.png
# ../outputs/tiled-satellite-images-rgb\5657.png
# ../outputs/tiled-satellite-images-rgb\5658.png
# ../outputs/tiled-satellite-images-rgb\5659.png
# ../outputs/tiled-satellite-images-rgb\5660.png
# ../outputs/tiled-satellite-images-rgb\5661.png
# ../outputs/tiled-satellite-images-rgb\5662.png
# ../outputs/tiled-satellite-images-rgb\5663.png
# ../outputs/tiled-satellite-images-rgb\5664.png
# ../outputs/tiled-satellite-images-rgb\5665.png
# ../outputs/tiled-satellite-images-rgb\5666.png
# ../outputs/tiled-satellite-images-rgb\5667.png
# ../outputs/tiled-satellite-images-rgb\5668.png
# ../outputs/tiled-satellite-images-rgb\5669.png
# ../outputs/tiled-satellite-images-rgb\5670.png
# ../outputs/tiled-satellite-images-rgb\5671.png
# ../outputs/tiled-satellite-images-rgb\5672.png
# ../outputs/tiled-satellite-images-rgb\5673.png
# ../outputs/tiled-satellite-images-rgb\5674.png
# ../outputs/tiled-satellite-images-rgb\5675.png
# ../outputs/tiled-satellite-images-rgb\5676.png
# ../outputs/tiled-satellite-images-rgb\5677.png
# ../outputs/tiled-satellite-images-rgb\5678.png
# ../outputs/tiled-satellite-images-rgb\5679.png
# ../outputs/tiled-satellite-images-rgb\5680.png
# ../outputs/tiled-satellite-images-rgb\5681.png
# ../outputs/tiled-satellite-images-rgb\5682.png
# ../outputs/tiled-satellite-images-rgb\5683.png
# ../outputs/tiled-satellite-images-rgb\5684.png
# ../outputs/tiled-satellite-images-rgb\5685.png
# ../outputs/tiled-satellite-images-rgb\5686.png
# ../outputs/tiled-satellite-images-rgb\5687.png
# ../outputs/tiled-satellite-images-rgb\5688.png
# ../outputs/tiled-satellite-images-rgb\5689.png
# ../outputs/tiled-satellite-images-rgb\5690.png
# ../outputs/tiled-satellite-images-rgb\5691.png
# ../outputs/tiled-satellite-images-rgb\5692.png
# ../outputs/tiled-satellite-images-rgb\5693.png
# ../outputs/tiled-satellite-images-rgb\5694.png
# ../outputs/tiled-satellite-images-rgb\5695.png
# ../outputs/tiled-satellite-images-rgb\5696.png
# ../outputs/tiled-satellite-images-rgb\5697.png
# ../outputs/tiled-satellite-images-rgb\5698.png
# ../outputs/tiled-satellite-images-rgb\5699.png
# ../outputs/tiled-satellite-images-rgb\5700.png
# ../outputs/tiled-satellite-images-rgb\5701.png
# ../outputs/tiled-satellite-images-rgb\5702.png
# ../outputs/tiled-satellite-images-rgb\5703.png
# ../outputs/tiled-satellite-images-rgb\5704.png
# ../outputs/tiled-satellite-images-rgb\5705.png
# ../outputs/tiled-satellite-images-rgb\5706.png
# ../outputs/tiled-satellite-images-rgb\5707.png
# ../outputs/tiled-satellite-images-rgb\5708.png
# ../outputs/tiled-satellite-images-rgb\5709.png
# ../outputs/tiled-satellite-images-rgb\5710.png
# ../outputs/tiled-satellite-images-rgb\5711.png
# ../outputs/tiled-satellite-images-rgb\5712.png
# ../outputs/tiled-satellite-images-rgb\5713.png
# ../outputs/tiled-satellite-images-rgb\5714.png
# ../outputs/tiled-satellite-images-rgb\5715.png
# ../outputs/tiled-satellite-images-rgb\5716.png
# ../outputs/tiled-satellite-images-rgb\5717.png
# ../outputs/tiled-satellite-images-rgb\5718.png
# ../outputs/tiled-satellite-images-rgb\5719.png
# ../outputs/tiled-satellite-images-rgb\5720.png
# ../outputs/tiled-satellite-images-rgb\5721.png
# ../outputs/tiled-satellite-images-rgb\5722.png
# ../outputs/tiled-satellite-images-rgb\5723.png
# ../outputs/tiled-satellite-images-rgb\5724.png
# ../outputs/tiled-satellite-images-rgb\5725.png
# ../outputs/tiled-satellite-images-rgb\5726.png
# ../outputs/tiled-satellite-images-rgb\5727.png
# ../outputs/tiled-satellite-images-rgb\5728.png
# ../outputs/tiled-satellite-images-rgb\5729.png
# ../outputs/tiled-satellite-images-rgb\5730.png
# ../outputs/tiled-satellite-images-rgb\5731.png
# ../outputs/tiled-satellite-images-rgb\5732.png
# ../outputs/tiled-satellite-images-rgb\5733.png
# ../outputs/tiled-satellite-images-rgb\5734.png
# ../outputs/tiled-satellite-images-rgb\5735.png
# ../outputs/tiled-satellite-images-rgb\5736.png
# ../outputs/tiled-satellite-images-rgb\5737.png
# ../outputs/tiled-satellite-images-rgb\5738.png
# ../outputs/tiled-satellite-images-rgb\5739.png
# ../outputs/tiled-satellite-images-rgb\5740.png
# ../outputs/tiled-satellite-images-rgb\5741.png
# ../outputs/tiled-satellite-images-rgb\5742.png
# ../outputs/tiled-satellite-images-rgb\5743.png
# ../outputs/tiled-satellite-images-rgb\5744.png
# ../outputs/tiled-satellite-images-rgb\5745.png
# ../outputs/tiled-satellite-images-rgb\5746.png
# ../outputs/tiled-satellite-images-rgb\5747.png
# ../outputs/tiled-satellite-images-rgb\5748.png
# ../outputs/tiled-satellite-images-rgb\5749.png
# ../outputs/tiled-satellite-images-rgb\5750.png
# ../outputs/tiled-satellite-images-rgb\5751.png
# ../outputs/tiled-satellite-images-rgb\5752.png
# ../outputs/tiled-satellite-images-rgb\5753.png
# ../outputs/tiled-satellite-images-rgb\5754.png
# ../outputs/tiled-satellite-images-rgb\5755.png
# ../outputs/tiled-satellite-images-rgb\5756.png
# ../outputs/tiled-satellite-images-rgb\5757.png
# ../outputs/tiled-satellite-images-rgb\5758.png
# ../outputs/tiled-satellite-images-rgb\5759.png
# ../outputs/tiled-satellite-images-rgb\5760.png
# ../outputs/tiled-satellite-images-rgb\5761.png
# ../outputs/tiled-satellite-images-rgb\5762.png
# ../outputs/tiled-satellite-images-rgb\5763.png
# ../outputs/tiled-satellite-images-rgb\5764.png
# ../outputs/tiled-satellite-images-rgb\5765.png
# ../outputs/tiled-satellite-images-rgb\5766.png
# ../outputs/tiled-satellite-images-rgb\5767.png
# ../outputs/tiled-satellite-images-rgb\5768.png
# ../outputs/tiled-satellite-images-rgb\5769.png
# ../outputs/tiled-satellite-images-rgb\5770.png
# ../outputs/tiled-satellite-images-rgb\5771.png
# ../outputs/tiled-satellite-images-rgb\5772.png
# ../outputs/tiled-satellite-images-rgb\5773.png
# ../outputs/tiled-satellite-images-rgb\5774.png
# ../outputs/tiled-satellite-images-rgb\5775.png
# ../outputs/tiled-satellite-images-rgb\5776.png
# ../outputs/tiled-satellite-images-rgb\5777.png
# ../outputs/tiled-satellite-images-rgb\5778.png
# ../outputs/tiled-satellite-images-rgb\5779.png
# ../outputs/tiled-satellite-images-rgb\5780.png
# ../outputs/tiled-satellite-images-rgb\5781.png
# ../outputs/tiled-satellite-images-rgb\5782.png
# ../outputs/tiled-satellite-images-rgb\5783.png
# ../outputs/tiled-satellite-images-rgb\5784.png
# ../outputs/tiled-satellite-images-rgb\5785.png
# ../outputs/tiled-satellite-images-rgb\5786.png
# ../outputs/tiled-satellite-images-rgb\5787.png
# ../outputs/tiled-satellite-images-rgb\5788.png
# ../outputs/tiled-satellite-images-rgb\5789.png
# ../outputs/tiled-satellite-images-rgb\5790.png
# ../outputs/tiled-satellite-images-rgb\5791.png
# ../outputs/tiled-satellite-images-rgb\5792.png
# ../outputs/tiled-satellite-images-rgb\5793.png
# ../outputs/tiled-satellite-images-rgb\5794.png
# ../outputs/tiled-satellite-images-rgb\5795.png
# ../outputs/tiled-satellite-images-rgb\5796.png
# ../outputs/tiled-satellite-images-rgb\5797.png
# ../outputs/tiled-satellite-images-rgb\5798.png
# ../outputs/tiled-satellite-images-rgb\5799.png
# ../outputs/tiled-satellite-images-rgb\5800.png
# ../outputs/tiled-satellite-images-rgb\5801.png
# ../outputs/tiled-satellite-images-rgb\5802.png
# ../outputs/tiled-satellite-images-rgb\5803.png
# ../outputs/tiled-satellite-images-rgb\5804.png
# ../outputs/tiled-satellite-images-rgb\5805.png
# ../outputs/tiled-satellite-images-rgb\5806.png
# ../outputs/tiled-satellite-images-rgb\5807.png
# ../outputs/tiled-satellite-images-rgb\5808.png
# ../outputs/tiled-satellite-images-rgb\5809.png
# ../outputs/tiled-satellite-images-rgb\5810.png
# ../outputs/tiled-satellite-images-rgb\5811.png
# ../outputs/tiled-satellite-images-rgb\5812.png
# ../outputs/tiled-satellite-images-rgb\5813.png
# ../outputs/tiled-satellite-images-rgb\5814.png
# ../outputs/tiled-satellite-images-rgb\5815.png
# ../outputs/tiled-satellite-images-rgb\5816.png
# ../outputs/tiled-satellite-images-rgb\5817.png
# ../outputs/tiled-satellite-images-rgb\5818.png
# ../outputs/tiled-satellite-images-rgb\5819.png
# ../outputs/tiled-satellite-images-rgb\5820.png
# ../outputs/tiled-satellite-images-rgb\5821.png
# ../outputs/tiled-satellite-images-rgb\5822.png
# ../outputs/tiled-satellite-images-rgb\5823.png
# ../outputs/tiled-satellite-images-rgb\5824.png
# ../outputs/tiled-satellite-images-rgb\5825.png
# ../outputs/tiled-satellite-images-rgb\5826.png
# ../outputs/tiled-satellite-images-rgb\5827.png
# ../outputs/tiled-satellite-images-rgb\5828.png
# ../outputs/tiled-satellite-images-rgb\5829.png
# ../outputs/tiled-satellite-images-rgb\5830.png
# ../outputs/tiled-satellite-images-rgb\5831.png
# ../outputs/tiled-satellite-images-rgb\5832.png
# ../outputs/tiled-satellite-images-rgb\5833.png
# ../outputs/tiled-satellite-images-rgb\5834.png
# ../outputs/tiled-satellite-images-rgb\5835.png
# ../outputs/tiled-satellite-images-rgb\5836.png
# ../outputs/tiled-satellite-images-rgb\5837.png
# ../outputs/tiled-satellite-images-rgb\5838.png
# ../outputs/tiled-satellite-images-rgb\5839.png
# ../outputs/tiled-satellite-images-rgb\5840.png
# ../outputs/tiled-satellite-images-rgb\5841.png
# ../outputs/tiled-satellite-images-rgb\5842.png
# ../outputs/tiled-satellite-images-rgb\5843.png
# ../outputs/tiled-satellite-images-rgb\5844.png
# ../outputs/tiled-satellite-images-rgb\5845.png
# ../outputs/tiled-satellite-images-rgb\5846.png
# ../outputs/tiled-satellite-images-rgb\5847.png
# ../outputs/tiled-satellite-images-rgb\5848.png
# ../outputs/tiled-satellite-images-rgb\5849.png
# ../outputs/tiled-satellite-images-rgb\5850.png
# Min training image width: 256 px
# Min training image height: 256 px

# %% [markdown]
# Reading and displaying images

# %% [markdown]
# ### Build the training dataset

# %%
from sklearn.model_selection import StratifiedShuffleSplit

data_path = '../outputs/clustered-data-gauteng.csv'
data = pd.read_csv(data_path)

# Use stratified sampling


sssplit = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
print(data.shape)
print(data['QoLIndex_Data_Driven'].shape)
for train_index,test_index in sssplit.split(data, data['QoLIndex_Data_Driven']):
    training_set = data.iloc[train_index]
    eval_set = data.iloc[test_index]
    
# Visually check the distribution of service_index score in training and test sets
training_set['QoLIndex_Data_Driven'].hist(label='Training set')
eval_set['QoLIndex_Data_Driven'].hist(label='Eval set')
plt.title('QoLIndex_Data_Driven score distribution in training and test set')
plt.xlabel('QoLIndex_Data_Driven score')
plt.ylabel('Count')
plt.legend(loc='upper right')
plt.show()

# Export training and test sets as .csv files
training_set['filename'] = training_set['ward_id'].apply(lambda x: f'../outputs/tiled-satellite-images-rgb/{x}.png')
training_set[['filename', 'QoLIndex_Data_Driven']].to_csv('../outputs/hack/working/training_set.csv', header=False, index=False)
eval_set['filename'] = eval_set['ward_id'].apply(lambda x: f'../outputs/tiled-satellite-images-rgb/{x}.png')
eval_set[['filename', 'QoLIndex_Data_Driven']].to_csv('../outputs/hack/working/eval_set.csv', header=False, index=False)
# Out:
# (2470, 12)
# (2470,)

# %% [markdown]
# ### Some functions

# %%
def read_and_decode(filename, reshape_dims):
    # Read an image file to a tensor as a sequence of bytes
    image = tf.io.read_file(filename)
    # Convert the tensor to a 3D uint8 tensor
    image = tf.image.decode_png(image, channels=IMG_CHANNELS)
    # Convert 3D uint8 tensor with values in [0, 1]
    image = tf.image.convert_image_dtype(image, tf.float32)
    # Resize the image to the desired size
    return tf.image.resize(image, reshape_dims)

def show_image(filename):
    image = read_and_decode(filename, [IMG_HEIGHT, IMG_WIDTH])
    plt.imshow(image.numpy())
    plt.axis('off')

def decode_csv(csv_row):
    record_defaults = ['filename', 'service_index']
    filename, service_index = tf.io.decode_csv(csv_row, record_defaults)
    service_index = tf.convert_to_tensor(np.float(service_index), dtype=tf.float32)
    image = read_and_decode(filename, [IMG_HEIGHT, IMG_WIDTH])
    return image, service_index

# %% [markdown]
# ## Import training & eval datasets

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3

path = '../outputs/tiled-satellite-images-rgb'
training_img = glob.glob(f'{path}/*.png')
rand_idx = np.random.randint(0, len(training_img)-1)
rand_img = training_img[rand_idx]

show_image(rand_img)

# %%
BATCH_SIZE = 256

train_dataset = tf.data.TextLineDataset(
    '../outputs/hack/working/training_set.csv'
).map(decode_csv).batch(BATCH_SIZE)

eval_dataset = tf.data.TextLineDataset(
    '../outputs/hack/working/eval_set.csv'
).map(decode_csv).batch(BATCH_SIZE)
# Out:
# C:\Users\emily\AppData\Local\Temp\__autograph_generated_fileoytvhbqp.py:12: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   service_index = ag__.converted_call(ag__.ld(tf).convert_to_tensor, (ag__.converted_call(ag__.ld(np).float, (ag__.ld(service_index),), None, fscope),), dict(dtype=ag__.ld(tf).float32), fscope)

# %% [markdown]
# ## Build CNN

# %%
# Build model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1, activation=None)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  flatten (Flatten)           (None, 1032256)           0
#
#  dense (Dense)               (None, 1)                 1032257
#
# =================================================================
# Total params: 1,034,049
# Trainable params: 1,034,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ## Notes & Takeaways
#
# - I was following [this tutorial](https://www.kaggle.com/code/emilyrosesteyn/convolutional-neural-network-for-image-regression/edit) for image regression
# - The shuffle split algorithm requires more image data than what I had clustered.
# - I want to build my pipeline:
#     - Data downloading (satellite image data, GCRO data, municipal boundaries data, DHS data for SA)
#     - Module for clustering data
#     - Module for downloading satellite images for clusters
#     -
