# %% [markdown]
# # Understanding the output of the resnet model
# I'm trying to determine if the features extracted by your modified ResNet50V2 model are correlated with the continuous variable (generalising to label from params) that I'm predicting. This is a critical step in understanding my model's behavior and identifying potential issues.

# %%
# NB! Only run this once
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /opt/emily/projects/measuring-quality-of-life-gauteng

# %%
import numpy as np
import tensorflow as tf
from dvc.api import params_show
from tensorflow.keras.models import load_model

from utils.r2_score import r_squared

label = params_show()["train"]["label"]
# Out:
# 2024-08-16 14:38:50.831820: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-16 14:38:52.426005: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-08-16 14:38:52.426105: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# ...

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2024-08-16 14:38:54.670772: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-16 14:38:55.357274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10777 MB memory:  -> device: 0, name: Tesla K40c, pci bus id: 0000:05:00.0, compute capability: 3.5

# %%
model = load_model("outputs/model/final.h5", custom_objects={"r_squared": r_squared})

# %%
model.summary()
# Out:
# Model: "ResNet50V2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_5[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 64, 64, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 64, 64, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
# ...

# %%
from utils.load_processed_data import load_dataset

training_data = load_dataset('train')
training_data
# Out:
#        index                         tile  year ward_code  services  \
# 0          0  2018-04-1179-868_00_05.tiff  2018  74804001  8.447754
# 1          1  2018-04-1179-868_00_08.tiff  2018  74804012  8.430467
# 2          2  2018-04-1179-868_00_09.tiff  2018  74804012  8.430467
# 3          3  2018-04-1179-868_00_10.tiff  2018  74804012  8.430467
# 4          4  2018-04-1179-868_00_11.tiff  2018  74804012  8.430467
# ...      ...                          ...   ...       ...       ...
# 16377  21857  2018-04-1184-870_15_10.tiff  2018  79700025  7.291546
# 16378  21858  2018-04-1184-870_15_11.tiff  2018  79700025  7.291546
# 16379  21859  2018-04-1184-870_15_12.tiff  2018  79700025  7.291546
# 16380  21860  2018-04-1184-870_15_13.tiff  2018  79700025  7.291546
# 16381  21861  2018-04-1184-870_15_14.tiff  2018  79700025  7.291546
#
#        socioeconomic_status  government_satisfaction  life_satisfaction  \
# 0                  2.686076                 5.115498           6.728948
# ...

# %%
training_data.shape[0]
# Out:
# 16382

# %%
from utils.keras_data_format import create_generator

train_generator = create_generator(training_data, label)
train_generator
# Out:
# Found 16382 validated image filenames.

# %%
y_predictions_v2 = model.predict(train_generator)
y_predictions_v2
# Out:
# 2024-08-16 14:39:17.453129: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2024-08-16 14:39:17.724976: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 512/512 [==============================] - 114s 215ms/step
# array([[58.20404 ],
#        [53.67649 ],
#        [52.44052 ],
#        ...,
#        [55.047276],
#        [55.729218],
#        [59.810497]], dtype=float32)

# %%
len(y_predictions_v2)
# Out:
# 16382

# %%
training_data["prediction"] = y_predictions_v2
training_data

# %%
import os
os.makedirs("./temp-outputs/misc", exist_ok=True)
training_data.to_csv("./temp-outputs/misc/predictions-train.csv", index=False)

# %%
y_target = training_data[label]
y_pred = training_data["prediction"]

# %%
from matplotlib import pyplot as plt

plt.scatter(y_target, y_pred, marker='.')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# ## Pearson's Correlation of training data - predicted number vs actual

# %%
final_predictions = np.array(y_pred)
np.shape(final_predictions)
# Out:
# (16382,)

# %%
target_all = np.array(y_target)
np.shape(target_all)
# Out:
# (16382,)

# %%
# Compute the Pearson correlation coefficient
correlation_np = np.corrcoef(final_predictions, target_all)[0, 1]
correlation_np
# Out:
# 0.0011759006130684676

# %%
from scipy.stats import pearsonr

# Compute the Pearson correlation coefficient and the p-value
correlation, p_value = pearsonr(final_predictions, target_all)
print("Pearson correlation coefficient:", correlation)
print("P-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.0011759006130684692
# P-value: 0.8803743642632409

# %% [markdown]
# ## Spearman's Rank Correlation of training data - predicted number vs actual

# %%
from scipy.stats import spearmanr

# Compute the Spearman rank correlation coefficient and the p-value
spearman_corr, spearman_p_value = spearmanr(final_predictions, target_all)

print("Spearman rank correlation coefficient:", spearman_corr)
print("P-value:", spearman_p_value)
# Out:
# Spearman rank correlation coefficient: -0.0037981933249925685
# P-value: 0.6268936230332127

# %% [markdown]
# ## Kendall's Tau Correlation of training data - predicted number vs actual

# %%
from scipy.stats import kendalltau

# Compute the Kendall tau correlation coefficient and the p-value
kendall_corr, kendall_p_value = kendalltau(final_predictions, target_all)

print("Kendall tau correlation coefficient:", kendall_corr)
print("P-value:", kendall_p_value)
# Out:
# Kendall tau correlation coefficient: -0.0025600183405606316
# P-value: 0.6262434545325193

# %% [markdown]
# ## Now trying to correlate feature matrix output with actual target variable

# %%
# Above I did predictions for the model (ie total overall predictions)
# Now I am just going to get the output of the resnet alone
from keras import Model

model_output = model.get_layer("post_relu").output
resnet_model = Model(inputs=model.input, outputs=model_output)

# This gets 32 samples from the generator
batch = next(train_generator)
batch
# Out:
# (array([[[[0.27058825, 0.24705884, 0.12941177],
#           [0.26666668, 0.24705884, 0.13725491],
#           [0.25882354, 0.2392157 , 0.13725491],
#           ...,
#           [0.20392159, 0.18431373, 0.11764707],
#           [0.21960786, 0.19215688, 0.12156864],
#           [0.21176472, 0.19215688, 0.11764707]],
#
#          [[0.25490198, 0.24313727, 0.12941177],
#           [0.25882354, 0.24705884, 0.13333334],
#           [0.27058825, 0.24313727, 0.13725491],
#           ...,
#           [0.20000002, 0.18039216, 0.10980393],
#           [0.20784315, 0.18431373, 0.11764707],
#           [0.21960786, 0.19215688, 0.11764707]],
#
#          [[0.2509804 , 0.24313727, 0.12941177],
#           [0.25882354, 0.24313727, 0.12941177],
#           [0.27058825, 0.24313727, 0.13725491],
#           ...,
#           [0.20000002, 0.1764706 , 0.10588236],
#           [0.20000002, 0.17254902, 0.1137255 ],
#           [0.20784315, 0.18431373, 0.12156864]],
#
#          ...,
#
# ...

# %%
img_tensors = batch[0]
img_tensors
# Out:
# array([[[[0.27058825, 0.24705884, 0.12941177],
#          [0.26666668, 0.24705884, 0.13725491],
#          [0.25882354, 0.2392157 , 0.13725491],
#          ...,
#          [0.20392159, 0.18431373, 0.11764707],
#          [0.21960786, 0.19215688, 0.12156864],
#          [0.21176472, 0.19215688, 0.11764707]],
#
#         [[0.25490198, 0.24313727, 0.12941177],
#          [0.25882354, 0.24705884, 0.13333334],
#          [0.27058825, 0.24313727, 0.13725491],
#          ...,
#          [0.20000002, 0.18039216, 0.10980393],
#          [0.20784315, 0.18431373, 0.11764707],
#          [0.21960786, 0.19215688, 0.11764707]],
#
#         [[0.2509804 , 0.24313727, 0.12941177],
#          [0.25882354, 0.24313727, 0.12941177],
#          [0.27058825, 0.24313727, 0.13725491],
#          ...,
#          [0.20000002, 0.1764706 , 0.10588236],
#          [0.20000002, 0.17254902, 0.1137255 ],
#          [0.20784315, 0.18431373, 0.12156864]],
#
#         ...,
#
# ...

# %%
extracted_features = resnet_model.predict(img_tensors)
extracted_features = np.array(extracted_features)

np.shape(extracted_features)
# Out:
# 1/1 [==============================] - 1s 1s/step
# (32, 8, 8, 2048)

# %%
# Reshape the feature matrix to (32, 8 * 8 * 2048)
flattened_feature_matrix = extracted_features.reshape(32, -1)

# Now flattened_feature_matrix is of shape (32, 131072)
flattened_feature_matrix.shape
# Out:
# (32, 131072)

# %%
target_variable_batch = batch[1]
target_variable_batch = np.array(target_variable_batch)
np.shape(target_variable_batch)
# Out:
# (32,)

# %%
from scipy.stats import pearsonr

# Initialize an array to store correlation coefficients
pearsons_correlation_coefficients = np.zeros(flattened_feature_matrix.shape[1])
spearmans_correlation_coefficients = np.zeros(flattened_feature_matrix.shape[1])
kendall_correlation_coefficients = np.zeros(flattened_feature_matrix.shape[1])

# Compute the Pearson correlation coefficient for each feature
for i in range(flattened_feature_matrix.shape[1]):
    feature_column = flattened_feature_matrix[:, i]
    if np.all(feature_column == feature_column[0]):
        # If the feature is constant, set correlation to NaN or some other indicator
        pearsons_correlation_coefficients[i] = np.nan
        spearmans_correlation_coefficients[i] = np.nan
        kendall_correlation_coefficients[i] = np.nan
    else:
        pearsons_correlation_coefficients[i], _ = pearsonr(feature_column, target_variable_batch)
        spearmans_correlation_coefficients[i], _ = spearmanr(feature_column, target_variable_batch)
        kendall_correlation_coefficients[i], _ = kendalltau(final_predictions, target_all)

# %% [markdown]
# ### Pearson's

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(range(len(pearsons_correlation_coefficients)), pearsons_correlation_coefficients)
plt.xlabel('Feature Index')
plt.ylabel('Pearson Correlation Coefficient')
plt.title('Correlation between ResNet Features and Target Value')
plt.show()

# %% [markdown]
# ### Spearman's Rank

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(range(len(spearmans_correlation_coefficients)), spearmans_correlation_coefficients)
plt.xlabel('Feature Index')
plt.ylabel('Spearman\'s Rank Correlation Coefficient')
plt.show()

# %% [markdown]
# ### Kendall's Tau

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(range(len(kendall_correlation_coefficients)), kendall_correlation_coefficients)
plt.xlabel('Feature Index')
plt.ylabel('Kendall Tau Correlation Coefficient')
plt.show()

# %% [markdown]
# ## TEST DATA

# %%
test_data = load_dataset('test')
test_data
# Out:
#       index                         tile  year ward_code  services  \
# 0       114  2018-04-1179-868_14_07.tiff  2018  74804018  9.400929
# 1       125  2021-01-1186-874_00_00.tiff  2021  79900099  5.639117
# 2       126  2021-01-1186-874_00_01.tiff  2021  79900099  5.639117
# 3       127  2021-01-1186-874_00_02.tiff  2021  79900099  5.639117
# 4       128  2021-01-1186-874_00_03.tiff  2021  79900099  5.639117
# ...     ...                          ...   ...       ...       ...
# 5475  21814  2018-04-1184-870_10_15.tiff  2018  79700017  9.398926
# 5476  21819  2018-04-1184-870_11_08.tiff  2018  79700091  9.397193
# 5477  21827  2018-04-1184-870_12_08.tiff  2018  79700091  9.397193
# 5478  21828  2018-04-1184-870_12_09.tiff  2018  79700091  9.397193
# 5479  21829  2018-04-1184-870_12_10.tiff  2018  79700091  9.397193
#
#       socioeconomic_status  government_satisfaction  life_satisfaction  \
# 0                 4.190993                 5.749581           7.156771
# ...

# %%
test_data.shape[0]
# Out:
# 5480

# %%
test_generator = create_generator(test_data, label)
test_generator
# Out:
# Found 5480 validated image filenames.

# %%
y_test_predictions_v2 = model.predict(test_generator)
y_test_predictions_v2
# Out:
# 172/172 [==============================] - 37s 215ms/step
# array([[50.866245],
#        [57.88012 ],
#        [58.786045],
#        ...,
#        [56.615368],
#        [55.526604],
#        [59.38506 ]], dtype=float32)

# %%
test_data["prediction"] = y_test_predictions_v2
test_data
# Out:
#       index                         tile  year ward_code  services  \
# 0       114  2018-04-1179-868_14_07.tiff  2018  74804018  9.400929
# 1       125  2021-01-1186-874_00_00.tiff  2021  79900099  5.639117
# 2       126  2021-01-1186-874_00_01.tiff  2021  79900099  5.639117
# 3       127  2021-01-1186-874_00_02.tiff  2021  79900099  5.639117
# 4       128  2021-01-1186-874_00_03.tiff  2021  79900099  5.639117
# ...     ...                          ...   ...       ...       ...
# 5475  21814  2018-04-1184-870_10_15.tiff  2018  79700017  9.398926
# 5476  21819  2018-04-1184-870_11_08.tiff  2018  79700091  9.397193
# 5477  21827  2018-04-1184-870_12_08.tiff  2018  79700091  9.397193
# 5478  21828  2018-04-1184-870_12_09.tiff  2018  79700091  9.397193
# 5479  21829  2018-04-1184-870_12_10.tiff  2018  79700091  9.397193
#
#       socioeconomic_status  government_satisfaction  life_satisfaction  \
# 0                 4.190993                 5.749581           7.156771
# ...

# %%
os.makedirs("./temp-outputs/misc", exist_ok=True)
test_data.to_csv("./temp-outputs/misc/predictions-test.csv", index=False)

# %%
y_target_test = test_data[label]
y_pred_test = test_data["prediction"]

# %%
from matplotlib import pyplot as plt

plt.scatter(y_target_test, y_pred_test, marker='.')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()
